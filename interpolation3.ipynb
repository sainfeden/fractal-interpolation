# %%
import numpy as np
import rasterio
from affine import Affine

import matplotlib.pyplot as plt
import time
import warnings

from skimage.filters.rank import entropy
from skimage.morphology import disk

# ==========================================================
# OPTIONAL GAUSSIAN PROCESS SUPPORT
# ==========================================================

USE_GAUSSIAN_PROCESS = False

if USE_GAUSSIAN_PROCESS:

    from sklearn.gaussian_process import GaussianProcessRegressor
    from sklearn.gaussian_process.kernels import RBF, WhiteKernel

    from sklearn.exceptions import ConvergenceWarning

    warnings.filterwarnings(
        "ignore",
        category=ConvergenceWarning
    )


# ==========================================================
# PARAMETERS
# ==========================================================

INPUT_IMAGE = (
    r"C:\Users\Fedor\Downloads\fractal-interpl\test"
    r"\2026-01-20-00_00_2026-01-20-23_59_"
    r"Sentinel-3_OLCI_True_color.tiff"
)

OUTPUT_ADAPTIVE = "adaptive_output.tif"
OUTPUT_GP = "gp_output.tif"

SCALE = 10

PATCH_SIZE = 5
OVERLAP = 2

ITERATIONS = 1


# ==========================================================
# FRACTAL FUNCTIONS
# ==========================================================

def d(x):

    return float(x[-1] - x[0])


def an(x, i):

    return (x[i] - x[i - 1]) / d(x)


def dn(x, i):

    return x[i - 1] / d(x)


def cn(x, y, i, sn):

    return (
        (y[i] - y[i - 1]) / d(x)
        -
        sn * ((y[-1] - y[0]) / d(x))
    )


def en(x, y, i, sn):

    return (
        (x[-1] * y[i - 1] - x[0] * y[i]) / d(x)
        -
        sn * (
            (x[-1] * y[0] - x[0] * y[-1])
            / d(x)
        )
    )


def Wn(X, U, i, sn):

    R = np.array([
        [an(U[:, 0], i), 0],
        [cn(U[:, 0], U[:, 1], i, sn), sn]
    ])

    T = np.array([
        dn(U[:, 0], i),
        en(U[:, 0], U[:, 1], i, sn)
    ])

    return R @ X + T


def G(U, sn):

    X = U.copy()

    x = list(X[:, 0])
    y = list(X[:, 1])

    M = U.shape[0]
    N = X.shape[0]

    for i in range(N):

        for j in range(1, M):

            xp, yp = Wn(X[i], U, j, sn)

            x.append(xp)
            y.append(yp)

    X = np.vstack((x, y)).T

    X = X[X[:, 0].argsort()]

    _, idx = np.unique(
        X[:, 0],
        return_index=True
    )

    return X[idx]


def FIF(U,
        sn=0.05,
        iterations=1):

    X = U.copy()

    for _ in range(iterations):

        X = G(X, sn)

    return X


# ==========================================================
# 1D FRACTAL INTERPOLATION
# ==========================================================

def fractal_interpolate_1d(signal,
                           scale=2,
                           sn=0.05,
                           iterations=1):

    n = len(signal)

    x = np.linspace(0, 1, n)

    U = np.vstack((x, signal)).T

    X = FIF(
        U,
        sn=sn,
        iterations=iterations
    )

    X = X[X[:, 0].argsort()]

    xi = np.linspace(
        0,
        1,
        n * scale
    )

    yi = np.interp(
        xi,
        X[:, 0],
        X[:, 1]
    )

    return yi


# ==========================================================
# OPTIONAL GP 1D INTERPOLATION
# ==========================================================

if USE_GAUSSIAN_PROCESS:

    def gp_interpolate_1d(signal,
                          scale=2,
                          length_scale=5.0,
                          noise=0.05):

        n = len(signal)

        x = np.arange(n).reshape(-1, 1)

        y = signal.astype(np.float32)

        kernel = (
            RBF(
                length_scale=length_scale,
                length_scale_bounds=(1e-2, 1e3)
            )
            +
            WhiteKernel(
                noise_level=noise,
                noise_level_bounds=(1e-8, 1e1)
            )
        )

        gp = GaussianProcessRegressor(
            kernel=kernel,
            alpha=1e-6,
            normalize_y=True,
            optimizer=None
        )

        gp.fit(x, y)

        xi = np.linspace(
            0,
            n - 1,
            n * scale
        ).reshape(-1, 1)

        yi = gp.predict(xi)

        return yi


# ==========================================================
# PATCH EXTRACTION
# ==========================================================

def extract_patches(img,
                    patch_size=32,
                    overlap=8):

    h, w, c = img.shape

    step = patch_size - overlap

    patches = []
    coords = []

    for y in range(
        0,
        h - patch_size + 1,
        step
    ):

        for x in range(
            0,
            w - patch_size + 1,
            step
        ):

            patch = img[
                y:y + patch_size,
                x:x + patch_size,
                :
            ]

            patches.append(patch)

            coords.append((y, x))

    return patches, coords


# ==========================================================
# ENTROPY
# ==========================================================

def compute_patch_entropy(patch):

    gray = np.mean(
        patch,
        axis=2
    ).astype(np.uint8)

    ent = entropy(
        gray,
        disk(3)
    )

    return np.mean(ent)


def entropy_to_sn(e):

    return 0.05 + 0.32 * (e / 8.0)


# ==========================================================
# FRACTAL PATCH UPSCALING
# ==========================================================

def upscale_patch(patch,
                  scale=2,
                  sn=0.05,
                  iterations=1):

    patch = patch.astype(np.float32)

    h, w, c = patch.shape

    out_rgb = np.zeros(
        (h * scale, w * scale, c),
        dtype=np.float32
    )

    for ch in range(c):

        channel = patch[:, :, ch]

        row_up = np.zeros(
            (h, w * scale),
            dtype=np.float32
        )

        for i in range(h):

            row_up[i] = fractal_interpolate_1d(
                channel[i],
                scale,
                sn,
                iterations
            )

        out = np.zeros(
            (h * scale, w * scale),
            dtype=np.float32
        )

        for j in range(w * scale):

            out[:, j] = fractal_interpolate_1d(
                row_up[:, j],
                scale,
                sn,
                iterations
            )

        out_rgb[:, :, ch] = out

    return out_rgb


# ==========================================================
# OPTIONAL GP PATCH UPSCALING
# ==========================================================

if USE_GAUSSIAN_PROCESS:

    def gp_upscale_patch(patch,
                         scale=2,
                         length_scale=5.0,
                         noise=0.05):

        patch = patch.astype(np.float32)

        h, w, c = patch.shape

        out_rgb = np.zeros(
            (h * scale, w * scale, c),
            dtype=np.float32
        )

        for ch in range(c):

            channel = patch[:, :, ch]

            row_up = np.zeros(
                (h, w * scale),
                dtype=np.float32
            )

            for i in range(h):

                row_up[i] = gp_interpolate_1d(
                    channel[i],
                    scale,
                    length_scale,
                    noise
                )

            out = np.zeros(
                (h * scale, w * scale),
                dtype=np.float32
            )

            for j in range(w * scale):

                out[:, j] = gp_interpolate_1d(
                    row_up[:, j],
                    scale,
                    length_scale,
                    noise
                )

            out_rgb[:, :, ch] = out

        return out_rgb


# ==========================================================
# RECONSTRUCTION
# ==========================================================

def reconstruct_image(patches,
                      coords,
                      shape,
                      scale=2,
                      patch_size=32):

    h, w, c = shape

    H = h * scale
    W = w * scale

    result = np.zeros(
        (H, W, c),
        dtype=np.float32
    )

    weight = np.zeros(
        (H, W, c),
        dtype=np.float32
    )

    scaled = patch_size * scale

    for patch, (y, x) in zip(
        patches,
        coords
    ):

        y2 = y * scale
        x2 = x * scale

        result[
            y2:y2 + scaled,
            x2:x2 + scaled
        ] += patch

        weight[
            y2:y2 + scaled,
            x2:x2 + scaled
        ] += 1

    result /= np.maximum(weight, 1e-8)

    return result


# ==========================================================
# ADAPTIVE FRACTAL UPSCALER
# ==========================================================

def adaptive_upscale(img):

    patches, coords = extract_patches(
        img,
        PATCH_SIZE,
        OVERLAP
    )

    results = []
    entropy_values = []

    for i, patch in enumerate(patches):

        ent = compute_patch_entropy(patch)

        entropy_values.append(ent)

        sn = entropy_to_sn(ent)

        print(
            f"Fractal "
            f"{i+1}/{len(patches)} "
            f"| entropy={ent:.2f} "
            f"| sn={sn:.3f}"
        )

        up = upscale_patch(
            patch,
            SCALE,
            sn,
            ITERATIONS
        )

        results.append(up)

    final = reconstruct_image(
        results,
        coords,
        img.shape,
        SCALE,
        PATCH_SIZE
    )

    return final, entropy_values, coords


# ==========================================================
# OPTIONAL GP UPSCALER
# ==========================================================

if USE_GAUSSIAN_PROCESS:

    def gp_upscale_image(img):

        patches, coords = extract_patches(
            img,
            PATCH_SIZE,
            OVERLAP
        )

        results = []

        for i, patch in enumerate(patches):

            print(
                f"GP "
                f"{i+1}/{len(patches)}"
            )

            up = gp_upscale_patch(
                patch,
                SCALE
            )

            results.append(up)

        final = reconstruct_image(
            results,
            coords,
            img.shape,
            SCALE,
            PATCH_SIZE
        )

        return final


# ==========================================================
# ENTROPY MAP
# ==========================================================

def build_entropy_map(shape,
                      coords,
                      entropy_values):

    h, w, _ = shape

    m = np.zeros(
        (h, w),
        dtype=np.float32
    )

    wgt = np.zeros(
        (h, w),
        dtype=np.float32
    )

    for e, (y, x) in zip(
        entropy_values,
        coords
    ):

        m[
            y:y + PATCH_SIZE,
            x:x + PATCH_SIZE
        ] += e

        wgt[
            y:y + PATCH_SIZE,
            x:x + PATCH_SIZE
        ] += 1

    return m / np.maximum(wgt, 1e-8)


# ==========================================================
# IMAGE LOADING
# ==========================================================

with rasterio.open(INPUT_IMAGE) as src:

    img = src.read()

    profile = src.profile.copy()

    transform = src.transform


# ----------------------------------------------------------
# CONVERT (bands, h, w) -> (h, w, bands)
# ----------------------------------------------------------

img = np.transpose(
    img,
    (1, 2, 0)
)


# ==========================================================
# NORMALIZE IMAGE
# ==========================================================

img = img.astype(np.float32)

img -= img.min()

img /= np.maximum(
    img.max(),
    1e-8
)

img *= 255

img = img.astype(np.uint8)


print("Image shape:", img.shape)


# ==========================================================
# RUN FRACTAL
# ==========================================================

start = time.time()

adaptive, entropy_values, coords = adaptive_upscale(img)

adaptive_time = time.time() - start

print(
    "\nFractal time:",
    adaptive_time
)


# ==========================================================
# OPTIONAL GP RUN
# ==========================================================

if USE_GAUSSIAN_PROCESS:

    start = time.time()

    gp_result = gp_upscale_image(img)

    gp_time = time.time() - start

    print(
        "GP time:",
        gp_time
    )


# ==========================================================
# OUTPUT PREP
# ==========================================================

adaptive_uint8 = np.clip(
    adaptive,
    0,
    255
).astype(np.uint8)

if USE_GAUSSIAN_PROCESS:

    gp_uint8 = np.clip(
        gp_result,
        0,
        255
    ).astype(np.uint8)


# ==========================================================
# UPDATE GEOREFERENCING
# ==========================================================

new_transform = transform * Affine.scale(
    1 / SCALE,
    1 / SCALE
)

profile.update(

    driver="GTiff",

    dtype=rasterio.uint8,

    count=img.shape[2],

    height=adaptive.shape[0],

    width=adaptive.shape[1],

    transform=new_transform
)
# Out:
# Image shape: (271, 285, 3)
# Fractal 1/8366 | entropy=3.07 | sn=0.173
# Fractal 2/8366 | entropy=2.92 | sn=0.167
# Fractal 3/8366 | entropy=3.19 | sn=0.178
# Fractal 4/8366 | entropy=3.12 | sn=0.175
# Fractal 5/8366 | entropy=3.04 | sn=0.172
# Fractal 6/8366 | entropy=2.97 | sn=0.169
# Fractal 7/8366 | entropy=3.09 | sn=0.174
# Fractal 8/8366 | entropy=3.11 | sn=0.174
# Fractal 9/8366 | entropy=3.05 | sn=0.172
# Fractal 10/8366 | entropy=3.16 | sn=0.176
# Fractal 11/8366 | entropy=3.21 | sn=0.178
# Fractal 12/8366 | entropy=2.73 | sn=0.159
# Fractal 13/8366 | entropy=2.51 | sn=0.150
# Fractal 14/8366 | entropy=2.91 | sn=0.166
# Fractal 15/8366 | entropy=2.86 | sn=0.164
# Fractal 16/8366 | entropy=3.15 | sn=0.176
# Fractal 17/8366 | entropy=3.06 | sn=0.173
# Fractal 18/8366 | entropy=3.07 | sn=0.173
# Fractal 19/8366 | entropy=2.88 | sn=0.165
# Fractal 20/8366 | entropy=2.89 | sn=0.165
# Fractal 21/8366 | entropy=2.99 | sn=0.169
# Fractal 22/8366 | entropy=2.85 | sn=0.164
# Fractal 23/8366 | entropy=3.27 | sn=0.181
# Fractal 24/8366 | entropy=3.07 | sn=0.173
# Fractal 25/8366 | entropy=2.72 | sn=0.159
# Fractal 26/8366 | entropy=2.97 | sn=0.169
# Fractal 27/8366 | entropy=3.19 | sn=0.178
# Fractal 28/8366 | entropy=3.22 | sn=0.179
# Fractal 29/8366 | entropy=2.97 | sn=0.169
# Fractal 30/8366 | entropy=2.98 | sn=0.169
# Fractal 31/8366 | entropy=2.83 | sn=0.163
# Fractal 32/8366 | entropy=3.02 | sn=0.171
# Fractal 33/8366 | entropy=3.05 | sn=0.172
# Fractal 34/8366 | entropy=3.11 | sn=0.174
# Fractal 35/8366 | entropy=3.12 | sn=0.175
# Fractal 36/8366 | entropy=3.06 | sn=0.172
# Fractal 37/8366 | entropy=3.02 | sn=0.171
# Fractal 38/8366 | entropy=2.74 | sn=0.160
# Fractal 39/8366 | entropy=2.99 | sn=0.169
# Fractal 40/8366 | entropy=3.13 | sn=0.175
# Fractal 41/8366 | entropy=3.00 | sn=0.170
# Fractal 42/8366 | entropy=3.24 | sn=0.179
# Fractal 43/8366 | entropy=2.87 | sn=0.165
# Fractal 44/8366 | entropy=3.23 | sn=0.179
# Fractal 45/8366 | entropy=3.00 | sn=0.170
# Fractal 46/8366 | entropy=3.16 | sn=0.176
# Fractal 47/8366 | entropy=2.73 | sn=0.159
# Fractal 48/8366 | entropy=3.02 | sn=0.171
# Fractal 49/8366 | entropy=3.17 | sn=0.177
# Fractal 50/8366 | entropy=3.13 | sn=0.175
# Fractal 51/8366 | entropy=3.15 | sn=0.176
# Fractal 52/8366 | entropy=2.81 | sn=0.162
# Fractal 53/8366 | entropy=2.68 | sn=0.157
# Fractal 54/8366 | entropy=3.10 | sn=0.174
# Fractal 55/8366 | entropy=3.15 | sn=0.176
# Fractal 56/8366 | entropy=3.28 | sn=0.181
# Fractal 57/8366 | entropy=3.16 | sn=0.176
# Fractal 58/8366 | entropy=3.21 | sn=0.179
# Fractal 59/8366 | entropy=3.15 | sn=0.176
# Fractal 60/8366 | entropy=3.25 | sn=0.180
# Fractal 61/8366 | entropy=2.74 | sn=0.159
# Fractal 62/8366 | entropy=3.17 | sn=0.177
# Fractal 63/8366 | entropy=2.94 | sn=0.167
# Fractal 64/8366 | entropy=3.15 | sn=0.176
# Fractal 65/8366 | entropy=3.23 | sn=0.179
# Fractal 66/8366 | entropy=2.56 | sn=0.152
# Fractal 67/8366 | entropy=0.98 | sn=0.089
# Fractal 68/8366 | entropy=2.57 | sn=0.153
# Fractal 69/8366 | entropy=3.12 | sn=0.175
# Fractal 70/8366 | entropy=2.98 | sn=0.169
# Fractal 71/8366 | entropy=2.99 | sn=0.170
# Fractal 72/8366 | entropy=2.23 | sn=0.139
# Fractal 73/8366 | entropy=1.26 | sn=0.101
# Fractal 74/8366 | entropy=3.17 | sn=0.177
# Fractal 75/8366 | entropy=3.06 | sn=0.173
# Fractal 76/8366 | entropy=2.92 | sn=0.167
# Fractal 77/8366 | entropy=3.24 | sn=0.180
# Fractal 78/8366 | entropy=3.16 | sn=0.176
# Fractal 79/8366 | entropy=3.15 | sn=0.176
# Fractal 80/8366 | entropy=3.09 | sn=0.174
# Fractal 81/8366 | entropy=3.14 | sn=0.175
# Fractal 82/8366 | entropy=3.16 | sn=0.177
# Fractal 83/8366 | entropy=3.22 | sn=0.179
# Fractal 84/8366 | entropy=3.13 | sn=0.175
# Fractal 85/8366 | entropy=3.16 | sn=0.176
# Fractal 86/8366 | entropy=3.21 | sn=0.178
# Fractal 87/8366 | entropy=3.08 | sn=0.173
# Fractal 88/8366 | entropy=3.07 | sn=0.173
# Fractal 89/8366 | entropy=3.15 | sn=0.176
# Fractal 90/8366 | entropy=2.96 | sn=0.168
# Fractal 91/8366 | entropy=2.73 | sn=0.159
# Fractal 92/8366 | entropy=3.12 | sn=0.175
# Fractal 93/8366 | entropy=3.10 | sn=0.174
# Fractal 94/8366 | entropy=2.97 | sn=0.169
# Fractal 95/8366 | entropy=3.13 | sn=0.175
# Fractal 96/8366 | entropy=3.15 | sn=0.176
# Fractal 97/8366 | entropy=3.16 | sn=0.176
# Fractal 98/8366 | entropy=3.10 | sn=0.174
# Fractal 99/8366 | entropy=2.98 | sn=0.169
# Fractal 100/8366 | entropy=2.74 | sn=0.160
# Fractal 101/8366 | entropy=3.14 | sn=0.175
# Fractal 102/8366 | entropy=3.20 | sn=0.178
# Fractal 103/8366 | entropy=3.13 | sn=0.175
# Fractal 104/8366 | entropy=3.02 | sn=0.171
# Fractal 105/8366 | entropy=3.09 | sn=0.174
# Fractal 106/8366 | entropy=3.12 | sn=0.175
# Fractal 107/8366 | entropy=2.57 | sn=0.153
# Fractal 108/8366 | entropy=2.90 | sn=0.166
# Fractal 109/8366 | entropy=2.95 | sn=0.168
# Fractal 110/8366 | entropy=3.09 | sn=0.174
# Fractal 111/8366 | entropy=2.95 | sn=0.168
# Fractal 112/8366 | entropy=2.84 | sn=0.163
# Fractal 113/8366 | entropy=2.55 | sn=0.152
# Fractal 114/8366 | entropy=2.88 | sn=0.165
# Fractal 115/8366 | entropy=3.00 | sn=0.170
# Fractal 116/8366 | entropy=3.06 | sn=0.172
# Fractal 117/8366 | entropy=2.99 | sn=0.170
# Fractal 118/8366 | entropy=3.17 | sn=0.177
# Fractal 119/8366 | entropy=3.02 | sn=0.171
# Fractal 120/8366 | entropy=3.05 | sn=0.172
# Fractal 121/8366 | entropy=3.18 | sn=0.177
# Fractal 122/8366 | entropy=3.14 | sn=0.176
# Fractal 123/8366 | entropy=3.06 | sn=0.172
# Fractal 124/8366 | entropy=3.13 | sn=0.175
# Fractal 125/8366 | entropy=2.79 | sn=0.162
# Fractal 126/8366 | entropy=2.95 | sn=0.168
# Fractal 127/8366 | entropy=2.93 | sn=0.167
# Fractal 128/8366 | entropy=2.78 | sn=0.161
# Fractal 129/8366 | entropy=2.91 | sn=0.166
# Fractal 130/8366 | entropy=3.07 | sn=0.173
# Fractal 131/8366 | entropy=3.09 | sn=0.173
# Fractal 132/8366 | entropy=3.05 | sn=0.172
# Fractal 133/8366 | entropy=3.09 | sn=0.174
# Fractal 134/8366 | entropy=3.10 | sn=0.174
# Fractal 135/8366 | entropy=3.26 | sn=0.180
# Fractal 136/8366 | entropy=3.25 | sn=0.180
# Fractal 137/8366 | entropy=3.12 | sn=0.175
# Fractal 138/8366 | entropy=2.94 | sn=0.168
# Fractal 139/8366 | entropy=3.13 | sn=0.175
# Fractal 140/8366 | entropy=3.24 | sn=0.179
# Fractal 141/8366 | entropy=3.13 | sn=0.175
# Fractal 142/8366 | entropy=3.13 | sn=0.175
# Fractal 143/8366 | entropy=3.21 | sn=0.178
# Fractal 144/8366 | entropy=2.98 | sn=0.169
# Fractal 145/8366 | entropy=3.22 | sn=0.179
# Fractal 146/8366 | entropy=3.13 | sn=0.175
# Fractal 147/8366 | entropy=2.81 | sn=0.162
# Fractal 148/8366 | entropy=2.69 | sn=0.158
# Fractal 149/8366 | entropy=3.11 | sn=0.175
# Fractal 150/8366 | entropy=3.12 | sn=0.175
# Fractal 151/8366 | entropy=2.87 | sn=0.165
# Fractal 152/8366 | entropy=2.90 | sn=0.166
# Fractal 153/8366 | entropy=3.03 | sn=0.171
# Fractal 154/8366 | entropy=3.26 | sn=0.180
# Fractal 155/8366 | entropy=2.87 | sn=0.165
# Fractal 156/8366 | entropy=3.20 | sn=0.178
# Fractal 157/8366 | entropy=2.84 | sn=0.164
# Fractal 158/8366 | entropy=2.29 | sn=0.142
# Fractal 159/8366 | entropy=2.99 | sn=0.170
# Fractal 160/8366 | entropy=2.21 | sn=0.139
# Fractal 161/8366 | entropy=1.69 | sn=0.118
# Fractal 162/8366 | entropy=3.11 | sn=0.175
# Fractal 163/8366 | entropy=3.08 | sn=0.173
# Fractal 164/8366 | entropy=2.94 | sn=0.168
# Fractal 165/8366 | entropy=3.05 | sn=0.172
# Fractal 166/8366 | entropy=2.67 | sn=0.157
# Fractal 167/8366 | entropy=2.63 | sn=0.155
# Fractal 168/8366 | entropy=3.27 | sn=0.181
# Fractal 169/8366 | entropy=3.08 | sn=0.173
# Fractal 170/8366 | entropy=3.11 | sn=0.175
# Fractal 171/8366 | entropy=2.86 | sn=0.165
# Fractal 172/8366 | entropy=2.70 | sn=0.158
# Fractal 173/8366 | entropy=2.94 | sn=0.168
# Fractal 174/8366 | entropy=3.06 | sn=0.172
# Fractal 175/8366 | entropy=3.13 | sn=0.175
# Fractal 176/8366 | entropy=3.10 | sn=0.174
# Fractal 177/8366 | entropy=3.16 | sn=0.176
# Fractal 178/8366 | entropy=3.28 | sn=0.181
# Fractal 179/8366 | entropy=3.07 | sn=0.173
# Fractal 180/8366 | entropy=3.27 | sn=0.181
# Fractal 181/8366 | entropy=2.74 | sn=0.160
# Fractal 182/8366 | entropy=3.22 | sn=0.179
# Fractal 183/8366 | entropy=3.15 | sn=0.176
# Fractal 184/8366 | entropy=3.07 | sn=0.173
# Fractal 185/8366 | entropy=2.87 | sn=0.165
# Fractal 186/8366 | entropy=3.12 | sn=0.175
# Fractal 187/8366 | entropy=3.01 | sn=0.170
# Fractal 188/8366 | entropy=3.14 | sn=0.176
# Fractal 189/8366 | entropy=2.90 | sn=0.166
# Fractal 190/8366 | entropy=3.13 | sn=0.175
# Fractal 191/8366 | entropy=3.11 | sn=0.174
# Fractal 192/8366 | entropy=3.21 | sn=0.178
# Fractal 193/8366 | entropy=3.18 | sn=0.177
# Fractal 194/8366 | entropy=3.26 | sn=0.180
# Fractal 195/8366 | entropy=3.24 | sn=0.179
# Fractal 196/8366 | entropy=3.11 | sn=0.174
# Fractal 197/8366 | entropy=3.16 | sn=0.176
# Fractal 198/8366 | entropy=2.93 | sn=0.167
# Fractal 199/8366 | entropy=2.66 | sn=0.156
# Fractal 200/8366 | entropy=3.01 | sn=0.171
# Fractal 201/8366 | entropy=3.05 | sn=0.172
# Fractal 202/8366 | entropy=3.12 | sn=0.175
# Fractal 203/8366 | entropy=3.12 | sn=0.175
# Fractal 204/8366 | entropy=2.99 | sn=0.169
# Fractal 205/8366 | entropy=3.02 | sn=0.171
# Fractal 206/8366 | entropy=2.94 | sn=0.168
# Fractal 207/8366 | entropy=3.04 | sn=0.172
# Fractal 208/8366 | entropy=3.14 | sn=0.175
# Fractal 209/8366 | entropy=3.13 | sn=0.175
# Fractal 210/8366 | entropy=3.35 | sn=0.184
# Fractal 211/8366 | entropy=3.16 | sn=0.177
# Fractal 212/8366 | entropy=3.12 | sn=0.175
# Fractal 213/8366 | entropy=3.01 | sn=0.170
# Fractal 214/8366 | entropy=3.10 | sn=0.174
# Fractal 215/8366 | entropy=3.01 | sn=0.170
# Fractal 216/8366 | entropy=3.04 | sn=0.172
# Fractal 217/8366 | entropy=2.89 | sn=0.166
# Fractal 218/8366 | entropy=3.01 | sn=0.171
# Fractal 219/8366 | entropy=2.97 | sn=0.169
# Fractal 220/8366 | entropy=3.10 | sn=0.174
# Fractal 221/8366 | entropy=2.90 | sn=0.166
# Fractal 222/8366 | entropy=3.18 | sn=0.177
# Fractal 223/8366 | entropy=3.12 | sn=0.175
# Fractal 224/8366 | entropy=3.19 | sn=0.178
# Fractal 225/8366 | entropy=3.08 | sn=0.173
# Fractal 226/8366 | entropy=3.11 | sn=0.174
# Fractal 227/8366 | entropy=3.15 | sn=0.176
# Fractal 228/8366 | entropy=3.06 | sn=0.172
# Fractal 229/8366 | entropy=3.22 | sn=0.179
# Fractal 230/8366 | entropy=3.22 | sn=0.179
# Fractal 231/8366 | entropy=3.18 | sn=0.177
# Fractal 232/8366 | entropy=3.13 | sn=0.175
# Fractal 233/8366 | entropy=3.08 | sn=0.173
# Fractal 234/8366 | entropy=3.01 | sn=0.170
# Fractal 235/8366 | entropy=3.14 | sn=0.176
# Fractal 236/8366 | entropy=3.12 | sn=0.175
# Fractal 237/8366 | entropy=3.10 | sn=0.174
# Fractal 238/8366 | entropy=3.11 | sn=0.174
# Fractal 239/8366 | entropy=3.12 | sn=0.175
# Fractal 240/8366 | entropy=3.27 | sn=0.181
# Fractal 241/8366 | entropy=3.13 | sn=0.175
# Fractal 242/8366 | entropy=3.07 | sn=0.173
# Fractal 243/8366 | entropy=3.14 | sn=0.176
# Fractal 244/8366 | entropy=3.07 | sn=0.173
# Fractal 245/8366 | entropy=2.83 | sn=0.163
# Fractal 246/8366 | entropy=2.94 | sn=0.167
# Fractal 247/8366 | entropy=2.74 | sn=0.160
# Fractal 248/8366 | entropy=3.08 | sn=0.173
# Fractal 249/8366 | entropy=3.00 | sn=0.170
# Fractal 250/8366 | entropy=3.07 | sn=0.173
# Fractal 251/8366 | entropy=2.98 | sn=0.169
# Fractal 252/8366 | entropy=3.09 | sn=0.174
# Fractal 253/8366 | entropy=3.00 | sn=0.170
# Fractal 254/8366 | entropy=2.78 | sn=0.161
# Fractal 255/8366 | entropy=3.12 | sn=0.175
# Fractal 256/8366 | entropy=3.01 | sn=0.171
# Fractal 257/8366 | entropy=3.12 | sn=0.175
# Fractal 258/8366 | entropy=2.96 | sn=0.168
# Fractal 259/8366 | entropy=2.88 | sn=0.165
# Fractal 260/8366 | entropy=3.28 | sn=0.181
# Fractal 261/8366 | entropy=2.79 | sn=0.162
# Fractal 262/8366 | entropy=2.95 | sn=0.168
# Fractal 263/8366 | entropy=2.83 | sn=0.163
# Fractal 264/8366 | entropy=2.86 | sn=0.164
# Fractal 265/8366 | entropy=2.97 | sn=0.169
# Fractal 266/8366 | entropy=3.19 | sn=0.177
# Fractal 267/8366 | entropy=3.21 | sn=0.178
# Fractal 268/8366 | entropy=3.17 | sn=0.177
# Fractal 269/8366 | entropy=2.95 | sn=0.168
# Fractal 270/8366 | entropy=3.09 | sn=0.174
# Fractal 271/8366 | entropy=2.98 | sn=0.169
# Fractal 272/8366 | entropy=3.24 | sn=0.179
# Fractal 273/8366 | entropy=3.26 | sn=0.180
# Fractal 274/8366 | entropy=3.27 | sn=0.181
# Fractal 275/8366 | entropy=2.79 | sn=0.162
# Fractal 276/8366 | entropy=2.90 | sn=0.166
# Fractal 277/8366 | entropy=3.07 | sn=0.173
# Fractal 278/8366 | entropy=2.91 | sn=0.166
# Fractal 279/8366 | entropy=3.10 | sn=0.174
# Fractal 280/8366 | entropy=3.24 | sn=0.180
# Fractal 281/8366 | entropy=3.14 | sn=0.175
# Fractal 282/8366 | entropy=3.15 | sn=0.176
# Fractal 283/8366 | entropy=3.10 | sn=0.174
# Fractal 284/8366 | entropy=2.89 | sn=0.166
# Fractal 285/8366 | entropy=3.16 | sn=0.177
# Fractal 286/8366 | entropy=2.94 | sn=0.168
# Fractal 287/8366 | entropy=2.71 | sn=0.159
# Fractal 288/8366 | entropy=3.12 | sn=0.175
# Fractal 289/8366 | entropy=3.08 | sn=0.173
# Fractal 290/8366 | entropy=2.93 | sn=0.167
# Fractal 291/8366 | entropy=2.84 | sn=0.163
# Fractal 292/8366 | entropy=3.01 | sn=0.171
# Fractal 293/8366 | entropy=3.08 | sn=0.173
# Fractal 294/8366 | entropy=3.05 | sn=0.172
# Fractal 295/8366 | entropy=3.08 | sn=0.173
# Fractal 296/8366 | entropy=3.03 | sn=0.171
# Fractal 297/8366 | entropy=3.15 | sn=0.176
# Fractal 298/8366 | entropy=2.80 | sn=0.162
# Fractal 299/8366 | entropy=2.86 | sn=0.164
# Fractal 300/8366 | entropy=2.68 | sn=0.157
# Fractal 301/8366 | entropy=2.66 | sn=0.157
# Fractal 302/8366 | entropy=2.90 | sn=0.166
# Fractal 303/8366 | entropy=3.11 | sn=0.174
# Fractal 304/8366 | entropy=3.16 | sn=0.176
# Fractal 305/8366 | entropy=3.00 | sn=0.170
# Fractal 306/8366 | entropy=3.22 | sn=0.179
# Fractal 307/8366 | entropy=3.12 | sn=0.175
# Fractal 308/8366 | entropy=3.22 | sn=0.179
# Fractal 309/8366 | entropy=3.12 | sn=0.175
# Fractal 310/8366 | entropy=2.93 | sn=0.167
# Fractal 311/8366 | entropy=2.72 | sn=0.159
# Fractal 312/8366 | entropy=3.05 | sn=0.172
# Fractal 313/8366 | entropy=2.80 | sn=0.162
# Fractal 314/8366 | entropy=3.08 | sn=0.173
# Fractal 315/8366 | entropy=2.91 | sn=0.166
# Fractal 316/8366 | entropy=3.02 | sn=0.171
# Fractal 317/8366 | entropy=3.13 | sn=0.175
# Fractal 318/8366 | entropy=2.99 | sn=0.170
# Fractal 319/8366 | entropy=2.93 | sn=0.167
# Fractal 320/8366 | entropy=2.95 | sn=0.168
# Fractal 321/8366 | entropy=3.10 | sn=0.174
# Fractal 322/8366 | entropy=2.89 | sn=0.166
# Fractal 323/8366 | entropy=3.30 | sn=0.182
# Fractal 324/8366 | entropy=3.08 | sn=0.173
# Fractal 325/8366 | entropy=3.21 | sn=0.178
# Fractal 326/8366 | entropy=3.18 | sn=0.177
# Fractal 327/8366 | entropy=3.12 | sn=0.175
# Fractal 328/8366 | entropy=2.89 | sn=0.166
# Fractal 329/8366 | entropy=2.90 | sn=0.166
# Fractal 330/8366 | entropy=3.11 | sn=0.174
# Fractal 331/8366 | entropy=3.21 | sn=0.178
# Fractal 332/8366 | entropy=3.17 | sn=0.177
# Fractal 333/8366 | entropy=3.15 | sn=0.176
# Fractal 334/8366 | entropy=3.07 | sn=0.173
# Fractal 335/8366 | entropy=2.96 | sn=0.168
# Fractal 336/8366 | entropy=3.12 | sn=0.175
# Fractal 337/8366 | entropy=3.13 | sn=0.175
# Fractal 338/8366 | entropy=2.97 | sn=0.169
# Fractal 339/8366 | entropy=3.01 | sn=0.170
# Fractal 340/8366 | entropy=3.15 | sn=0.176
# Fractal 341/8366 | entropy=3.07 | sn=0.173
# Fractal 342/8366 | entropy=3.15 | sn=0.176
# Fractal 343/8366 | entropy=3.09 | sn=0.174
# Fractal 344/8366 | entropy=3.22 | sn=0.179
# Fractal 345/8366 | entropy=2.92 | sn=0.167
# Fractal 346/8366 | entropy=3.05 | sn=0.172
# Fractal 347/8366 | entropy=2.87 | sn=0.165
# Fractal 348/8366 | entropy=3.08 | sn=0.173
# Fractal 349/8366 | entropy=3.13 | sn=0.175
# Fractal 350/8366 | entropy=3.04 | sn=0.171
# Fractal 351/8366 | entropy=2.90 | sn=0.166
# Fractal 352/8366 | entropy=2.05 | sn=0.132
# Fractal 353/8366 | entropy=1.45 | sn=0.108
# Fractal 354/8366 | entropy=2.81 | sn=0.163
# Fractal 355/8366 | entropy=2.44 | sn=0.148
# Fractal 356/8366 | entropy=2.02 | sn=0.131
# Fractal 357/8366 | entropy=2.56 | sn=0.153
# Fractal 358/8366 | entropy=3.05 | sn=0.172
# Fractal 359/8366 | entropy=3.12 | sn=0.175
# Fractal 360/8366 | entropy=3.22 | sn=0.179
# Fractal 361/8366 | entropy=3.09 | sn=0.174
# Fractal 362/8366 | entropy=2.98 | sn=0.169
# Fractal 363/8366 | entropy=2.82 | sn=0.163
# Fractal 364/8366 | entropy=3.11 | sn=0.174
# Fractal 365/8366 | entropy=3.14 | sn=0.175
# Fractal 366/8366 | entropy=3.39 | sn=0.186
# Fractal 367/8366 | entropy=3.30 | sn=0.182
# Fractal 368/8366 | entropy=3.20 | sn=0.178
# Fractal 369/8366 | entropy=3.10 | sn=0.174
# Fractal 370/8366 | entropy=2.98 | sn=0.169
# Fractal 371/8366 | entropy=2.91 | sn=0.166
# Fractal 372/8366 | entropy=2.89 | sn=0.166
# Fractal 373/8366 | entropy=3.01 | sn=0.170
# Fractal 374/8366 | entropy=2.84 | sn=0.163
# Fractal 375/8366 | entropy=3.11 | sn=0.174
# Fractal 376/8366 | entropy=2.92 | sn=0.167
# Fractal 377/8366 | entropy=3.24 | sn=0.179
# Fractal 378/8366 | entropy=2.98 | sn=0.169
# Fractal 379/8366 | entropy=2.96 | sn=0.168
# Fractal 380/8366 | entropy=3.12 | sn=0.175
# Fractal 381/8366 | entropy=3.16 | sn=0.176
# Fractal 382/8366 | entropy=2.96 | sn=0.168
# Fractal 383/8366 | entropy=2.87 | sn=0.165
# Fractal 384/8366 | entropy=2.83 | sn=0.163
# Fractal 385/8366 | entropy=2.82 | sn=0.163
# Fractal 386/8366 | entropy=2.92 | sn=0.167
# Fractal 387/8366 | entropy=3.00 | sn=0.170
# Fractal 388/8366 | entropy=3.15 | sn=0.176
# Fractal 389/8366 | entropy=3.08 | sn=0.173
# Fractal 390/8366 | entropy=2.99 | sn=0.169
# Fractal 391/8366 | entropy=2.98 | sn=0.169
# Fractal 392/8366 | entropy=2.85 | sn=0.164
# Fractal 393/8366 | entropy=3.14 | sn=0.175
# Fractal 394/8366 | entropy=3.07 | sn=0.173
# Fractal 395/8366 | entropy=2.98 | sn=0.169
# Fractal 396/8366 | entropy=3.10 | sn=0.174
# Fractal 397/8366 | entropy=3.04 | sn=0.171
# Fractal 398/8366 | entropy=3.14 | sn=0.175
# Fractal 399/8366 | entropy=3.01 | sn=0.171
# Fractal 400/8366 | entropy=3.13 | sn=0.175
# Fractal 401/8366 | entropy=3.05 | sn=0.172
# Fractal 402/8366 | entropy=3.09 | sn=0.174
# Fractal 403/8366 | entropy=2.99 | sn=0.169
# Fractal 404/8366 | entropy=3.06 | sn=0.172
# Fractal 405/8366 | entropy=2.87 | sn=0.165
# Fractal 406/8366 | entropy=2.70 | sn=0.158
# Fractal 407/8366 | entropy=3.02 | sn=0.171
# Fractal 408/8366 | entropy=2.62 | sn=0.155
# Fractal 409/8366 | entropy=1.76 | sn=0.120
# Fractal 410/8366 | entropy=2.13 | sn=0.135
# Fractal 411/8366 | entropy=2.18 | sn=0.137
# Fractal 412/8366 | entropy=3.21 | sn=0.179
# Fractal 413/8366 | entropy=3.16 | sn=0.176
# Fractal 414/8366 | entropy=2.94 | sn=0.168
# Fractal 415/8366 | entropy=3.28 | sn=0.181
# Fractal 416/8366 | entropy=3.11 | sn=0.174
# Fractal 417/8366 | entropy=3.26 | sn=0.180
# Fractal 418/8366 | entropy=3.17 | sn=0.177
# Fractal 419/8366 | entropy=2.88 | sn=0.165
# Fractal 420/8366 | entropy=2.97 | sn=0.169
# Fractal 421/8366 | entropy=3.05 | sn=0.172
# Fractal 422/8366 | entropy=2.98 | sn=0.169
# Fractal 423/8366 | entropy=3.06 | sn=0.172
# Fractal 424/8366 | entropy=3.03 | sn=0.171
# Fractal 425/8366 | entropy=3.13 | sn=0.175
# Fractal 426/8366 | entropy=3.26 | sn=0.180
# Fractal 427/8366 | entropy=3.15 | sn=0.176
# Fractal 428/8366 | entropy=2.76 | sn=0.160
# Fractal 429/8366 | entropy=2.64 | sn=0.156
# Fractal 430/8366 | entropy=2.86 | sn=0.164
# Fractal 431/8366 | entropy=3.18 | sn=0.177
# Fractal 432/8366 | entropy=3.14 | sn=0.175
# Fractal 433/8366 | entropy=2.81 | sn=0.162
# Fractal 434/8366 | entropy=3.28 | sn=0.181
# Fractal 435/8366 | entropy=3.13 | sn=0.175
# Fractal 436/8366 | entropy=3.17 | sn=0.177
# Fractal 437/8366 | entropy=3.08 | sn=0.173
# Fractal 438/8366 | entropy=3.19 | sn=0.177
# Fractal 439/8366 | entropy=2.85 | sn=0.164
# Fractal 440/8366 | entropy=2.97 | sn=0.169
# Fractal 441/8366 | entropy=2.95 | sn=0.168
# Fractal 442/8366 | entropy=3.13 | sn=0.175
# Fractal 443/8366 | entropy=3.09 | sn=0.174
# Fractal 444/8366 | entropy=2.29 | sn=0.142
# Fractal 445/8366 | entropy=2.04 | sn=0.132
# Fractal 446/8366 | entropy=1.25 | sn=0.100
# Fractal 447/8366 | entropy=2.49 | sn=0.150
# Fractal 448/8366 | entropy=2.94 | sn=0.168
# Fractal 449/8366 | entropy=1.74 | sn=0.120
# Fractal 450/8366 | entropy=2.86 | sn=0.164
# Fractal 451/8366 | entropy=3.05 | sn=0.172
# Fractal 452/8366 | entropy=3.26 | sn=0.180
# Fractal 453/8366 | entropy=3.21 | sn=0.178
# Fractal 454/8366 | entropy=3.23 | sn=0.179
# Fractal 455/8366 | entropy=2.97 | sn=0.169
# Fractal 456/8366 | entropy=3.29 | sn=0.182
# Fractal 457/8366 | entropy=3.25 | sn=0.180
# Fractal 458/8366 | entropy=3.18 | sn=0.177
# Fractal 459/8366 | entropy=3.09 | sn=0.174
# Fractal 460/8366 | entropy=3.06 | sn=0.172
# Fractal 461/8366 | entropy=3.19 | sn=0.178
# Fractal 462/8366 | entropy=2.86 | sn=0.164
# Fractal 463/8366 | entropy=2.97 | sn=0.169
# Fractal 464/8366 | entropy=3.13 | sn=0.175
# Fractal 465/8366 | entropy=2.91 | sn=0.166
# Fractal 466/8366 | entropy=2.69 | sn=0.157
# Fractal 467/8366 | entropy=2.56 | sn=0.153
# Fractal 468/8366 | entropy=2.51 | sn=0.150
# Fractal 469/8366 | entropy=2.85 | sn=0.164
# Fractal 470/8366 | entropy=3.08 | sn=0.173
# Fractal 471/8366 | entropy=3.35 | sn=0.184
# Fractal 472/8366 | entropy=2.99 | sn=0.169
# Fractal 473/8366 | entropy=3.07 | sn=0.173
# Fractal 474/8366 | entropy=3.12 | sn=0.175
# Fractal 475/8366 | entropy=2.70 | sn=0.158
# Fractal 476/8366 | entropy=2.78 | sn=0.161
# Fractal 477/8366 | entropy=2.74 | sn=0.160
# Fractal 478/8366 | entropy=3.12 | sn=0.175
# Fractal 479/8366 | entropy=3.07 | sn=0.173
# Fractal 480/8366 | entropy=2.94 | sn=0.168
# Fractal 481/8366 | entropy=3.12 | sn=0.175
# Fractal 482/8366 | entropy=3.08 | sn=0.173
# Fractal 483/8366 | entropy=2.97 | sn=0.169
# Fractal 484/8366 | entropy=2.98 | sn=0.169
# Fractal 485/8366 | entropy=2.85 | sn=0.164
# Fractal 486/8366 | entropy=2.72 | sn=0.159
# Fractal 487/8366 | entropy=3.03 | sn=0.171
# Fractal 488/8366 | entropy=3.00 | sn=0.170
# Fractal 489/8366 | entropy=2.88 | sn=0.165
# Fractal 490/8366 | entropy=3.24 | sn=0.179
# Fractal 491/8366 | entropy=3.10 | sn=0.174
# Fractal 492/8366 | entropy=3.22 | sn=0.179
# Fractal 493/8366 | entropy=3.09 | sn=0.174
# Fractal 494/8366 | entropy=3.27 | sn=0.181
# Fractal 495/8366 | entropy=3.12 | sn=0.175
# Fractal 496/8366 | entropy=3.22 | sn=0.179
# Fractal 497/8366 | entropy=3.07 | sn=0.173
# Fractal 498/8366 | entropy=3.17 | sn=0.177
# Fractal 499/8366 | entropy=2.99 | sn=0.169
# Fractal 500/8366 | entropy=3.01 | sn=0.170
# Fractal 501/8366 | entropy=3.12 | sn=0.175
# Fractal 502/8366 | entropy=3.03 | sn=0.171
# Fractal 503/8366 | entropy=2.57 | sn=0.153
# Fractal 504/8366 | entropy=2.63 | sn=0.155
# Fractal 505/8366 | entropy=2.80 | sn=0.162
# Fractal 506/8366 | entropy=2.85 | sn=0.164
# Fractal 507/8366 | entropy=3.17 | sn=0.177
# Fractal 508/8366 | entropy=3.05 | sn=0.172
# Fractal 509/8366 | entropy=3.19 | sn=0.178
# Fractal 510/8366 | entropy=3.21 | sn=0.178
# Fractal 511/8366 | entropy=3.20 | sn=0.178
# Fractal 512/8366 | entropy=3.15 | sn=0.176
# Fractal 513/8366 | entropy=3.10 | sn=0.174
# Fractal 514/8366 | entropy=2.79 | sn=0.162
# Fractal 515/8366 | entropy=2.83 | sn=0.163
# Fractal 516/8366 | entropy=3.07 | sn=0.173
# Fractal 517/8366 | entropy=3.06 | sn=0.172
# Fractal 518/8366 | entropy=2.74 | sn=0.160
# Fractal 519/8366 | entropy=3.05 | sn=0.172
# Fractal 520/8366 | entropy=3.27 | sn=0.181
# Fractal 521/8366 | entropy=3.15 | sn=0.176
# Fractal 522/8366 | entropy=2.86 | sn=0.164
# Fractal 523/8366 | entropy=2.78 | sn=0.161
# Fractal 524/8366 | entropy=3.15 | sn=0.176
# Fractal 525/8366 | entropy=3.27 | sn=0.181
# Fractal 526/8366 | entropy=3.13 | sn=0.175
# Fractal 527/8366 | entropy=2.81 | sn=0.162
# Fractal 528/8366 | entropy=3.03 | sn=0.171
# Fractal 529/8366 | entropy=2.91 | sn=0.166
# Fractal 530/8366 | entropy=3.09 | sn=0.174
# Fractal 531/8366 | entropy=3.13 | sn=0.175
# Fractal 532/8366 | entropy=3.14 | sn=0.175
# Fractal 533/8366 | entropy=2.41 | sn=0.146
# Fractal 534/8366 | entropy=3.02 | sn=0.171
# Fractal 535/8366 | entropy=3.01 | sn=0.170
# Fractal 536/8366 | entropy=3.12 | sn=0.175
# Fractal 537/8366 | entropy=1.61 | sn=0.114
# Fractal 538/8366 | entropy=0.80 | sn=0.082
# Fractal 539/8366 | entropy=2.76 | sn=0.160
# Fractal 540/8366 | entropy=3.16 | sn=0.176
# Fractal 541/8366 | entropy=3.17 | sn=0.177
# Fractal 542/8366 | entropy=3.08 | sn=0.173
# Fractal 543/8366 | entropy=3.16 | sn=0.176
# Fractal 544/8366 | entropy=3.28 | sn=0.181
# Fractal 545/8366 | entropy=3.08 | sn=0.173
# Fractal 546/8366 | entropy=3.29 | sn=0.182
# Fractal 547/8366 | entropy=3.14 | sn=0.176
# Fractal 548/8366 | entropy=2.97 | sn=0.169
# Fractal 549/8366 | entropy=2.89 | sn=0.165
# Fractal 550/8366 | entropy=2.54 | sn=0.152
# Fractal 551/8366 | entropy=2.89 | sn=0.166
# Fractal 552/8366 | entropy=3.09 | sn=0.173
# Fractal 553/8366 | entropy=2.91 | sn=0.166
# Fractal 554/8366 | entropy=3.07 | sn=0.173
# Fractal 555/8366 | entropy=3.02 | sn=0.171
# Fractal 556/8366 | entropy=3.07 | sn=0.173
# Fractal 557/8366 | entropy=3.06 | sn=0.172
# Fractal 558/8366 | entropy=2.72 | sn=0.159
# Fractal 559/8366 | entropy=2.66 | sn=0.156
# Fractal 560/8366 | entropy=3.15 | sn=0.176
# Fractal 561/8366 | entropy=3.09 | sn=0.174
# Fractal 562/8366 | entropy=2.67 | sn=0.157
# Fractal 563/8366 | entropy=2.85 | sn=0.164
# Fractal 564/8366 | entropy=3.03 | sn=0.171
# Fractal 565/8366 | entropy=3.17 | sn=0.177
# Fractal 566/8366 | entropy=3.16 | sn=0.177
# Fractal 567/8366 | entropy=3.17 | sn=0.177
# Fractal 568/8366 | entropy=3.07 | sn=0.173
# Fractal 569/8366 | entropy=2.63 | sn=0.155
# Fractal 570/8366 | entropy=2.82 | sn=0.163
# Fractal 571/8366 | entropy=2.76 | sn=0.161
# Fractal 572/8366 | entropy=3.07 | sn=0.173
# Fractal 573/8366 | entropy=3.10 | sn=0.174
# Fractal 574/8366 | entropy=3.09 | sn=0.174
# Fractal 575/8366 | entropy=3.11 | sn=0.174
# Fractal 576/8366 | entropy=3.24 | sn=0.179
# Fractal 577/8366 | entropy=3.02 | sn=0.171
# Fractal 578/8366 | entropy=3.13 | sn=0.175
# Fractal 579/8366 | entropy=2.99 | sn=0.170
# Fractal 580/8366 | entropy=3.18 | sn=0.177
# Fractal 581/8366 | entropy=3.12 | sn=0.175
# Fractal 582/8366 | entropy=3.12 | sn=0.175
# Fractal 583/8366 | entropy=3.12 | sn=0.175
# Fractal 584/8366 | entropy=3.27 | sn=0.181
# Fractal 585/8366 | entropy=3.21 | sn=0.178
# Fractal 586/8366 | entropy=3.11 | sn=0.174
# Fractal 587/8366 | entropy=3.11 | sn=0.175
# Fractal 588/8366 | entropy=3.29 | sn=0.181
# Fractal 589/8366 | entropy=3.10 | sn=0.174
# Fractal 590/8366 | entropy=3.04 | sn=0.171
# Fractal 591/8366 | entropy=2.80 | sn=0.162
# Fractal 592/8366 | entropy=2.93 | sn=0.167
# Fractal 593/8366 | entropy=2.96 | sn=0.168
# Fractal 594/8366 | entropy=2.73 | sn=0.159
# Fractal 595/8366 | entropy=2.83 | sn=0.163
# Fractal 596/8366 | entropy=2.64 | sn=0.156
# Fractal 597/8366 | entropy=2.79 | sn=0.162
# Fractal 598/8366 | entropy=2.64 | sn=0.156
# Fractal 599/8366 | entropy=2.88 | sn=0.165
# Fractal 600/8366 | entropy=3.19 | sn=0.178
# Fractal 601/8366 | entropy=3.15 | sn=0.176
# Fractal 602/8366 | entropy=2.80 | sn=0.162
# Fractal 603/8366 | entropy=3.14 | sn=0.176
# Fractal 604/8366 | entropy=3.06 | sn=0.172
# Fractal 605/8366 | entropy=3.12 | sn=0.175
# Fractal 606/8366 | entropy=3.11 | sn=0.174
# Fractal 607/8366 | entropy=3.05 | sn=0.172
# Fractal 608/8366 | entropy=3.20 | sn=0.178
# Fractal 609/8366 | entropy=2.89 | sn=0.166
# Fractal 610/8366 | entropy=3.09 | sn=0.174
# Fractal 611/8366 | entropy=2.60 | sn=0.154
# Fractal 612/8366 | entropy=2.94 | sn=0.168
# Fractal 613/8366 | entropy=3.25 | sn=0.180
# Fractal 614/8366 | entropy=3.27 | sn=0.181
# Fractal 615/8366 | entropy=3.21 | sn=0.178
# Fractal 616/8366 | entropy=3.07 | sn=0.173
# Fractal 617/8366 | entropy=3.10 | sn=0.174
# Fractal 618/8366 | entropy=3.12 | sn=0.175
# Fractal 619/8366 | entropy=3.15 | sn=0.176
# Fractal 620/8366 | entropy=3.14 | sn=0.176
# Fractal 621/8366 | entropy=2.77 | sn=0.161
# Fractal 622/8366 | entropy=3.22 | sn=0.179
# Fractal 623/8366 | entropy=3.14 | sn=0.176
# Fractal 624/8366 | entropy=3.11 | sn=0.174
# Fractal 625/8366 | entropy=3.00 | sn=0.170
# Fractal 626/8366 | entropy=2.61 | sn=0.155
# Fractal 627/8366 | entropy=2.28 | sn=0.141
# Fractal 628/8366 | entropy=3.09 | sn=0.174
# Fractal 629/8366 | entropy=2.70 | sn=0.158
# Fractal 630/8366 | entropy=2.82 | sn=0.163
# Fractal 631/8366 | entropy=1.41 | sn=0.106
# Fractal 632/8366 | entropy=2.29 | sn=0.142
# Fractal 633/8366 | entropy=3.22 | sn=0.179
# Fractal 634/8366 | entropy=3.08 | sn=0.173
# Fractal 635/8366 | entropy=3.15 | sn=0.176
# Fractal 636/8366 | entropy=3.14 | sn=0.175
# Fractal 637/8366 | entropy=3.16 | sn=0.176
# Fractal 638/8366 | entropy=3.17 | sn=0.177
# Fractal 639/8366 | entropy=2.95 | sn=0.168
# Fractal 640/8366 | entropy=2.97 | sn=0.169
# Fractal 641/8366 | entropy=2.85 | sn=0.164
# Fractal 642/8366 | entropy=2.62 | sn=0.155
# Fractal 643/8366 | entropy=2.19 | sn=0.138
# Fractal 644/8366 | entropy=2.21 | sn=0.139
# Fractal 645/8366 | entropy=2.93 | sn=0.167
# Fractal 646/8366 | entropy=2.96 | sn=0.168
# Fractal 647/8366 | entropy=2.68 | sn=0.157
# Fractal 648/8366 | entropy=3.20 | sn=0.178
# Fractal 649/8366 | entropy=3.19 | sn=0.178
# Fractal 650/8366 | entropy=3.22 | sn=0.179
# Fractal 651/8366 | entropy=2.85 | sn=0.164
# Fractal 652/8366 | entropy=2.68 | sn=0.157
# Fractal 653/8366 | entropy=2.96 | sn=0.168
# Fractal 654/8366 | entropy=3.04 | sn=0.172
# Fractal 655/8366 | entropy=3.06 | sn=0.172
# Fractal 656/8366 | entropy=3.03 | sn=0.171
# Fractal 657/8366 | entropy=3.08 | sn=0.173
# Fractal 658/8366 | entropy=3.19 | sn=0.177
# Fractal 659/8366 | entropy=3.27 | sn=0.181
# Fractal 660/8366 | entropy=3.24 | sn=0.180
# Fractal 661/8366 | entropy=3.13 | sn=0.175
# Fractal 662/8366 | entropy=3.14 | sn=0.176
# Fractal 663/8366 | entropy=3.11 | sn=0.174
# Fractal 664/8366 | entropy=3.13 | sn=0.175
# Fractal 665/8366 | entropy=3.22 | sn=0.179
# Fractal 666/8366 | entropy=2.98 | sn=0.169
# Fractal 667/8366 | entropy=3.06 | sn=0.173
# Fractal 668/8366 | entropy=3.08 | sn=0.173
# Fractal 669/8366 | entropy=3.13 | sn=0.175
# Fractal 670/8366 | entropy=3.13 | sn=0.175
# Fractal 671/8366 | entropy=2.95 | sn=0.168
# Fractal 672/8366 | entropy=3.10 | sn=0.174
# Fractal 673/8366 | entropy=3.11 | sn=0.175
# Fractal 674/8366 | entropy=2.97 | sn=0.169
# Fractal 675/8366 | entropy=2.98 | sn=0.169
# Fractal 676/8366 | entropy=2.96 | sn=0.168
# Fractal 677/8366 | entropy=3.05 | sn=0.172
# Fractal 678/8366 | entropy=3.19 | sn=0.178
# Fractal 679/8366 | entropy=3.05 | sn=0.172
# Fractal 680/8366 | entropy=3.07 | sn=0.173
# Fractal 681/8366 | entropy=3.02 | sn=0.171
# Fractal 682/8366 | entropy=3.15 | sn=0.176
# Fractal 683/8366 | entropy=3.12 | sn=0.175
# Fractal 684/8366 | entropy=3.04 | sn=0.172
# Fractal 685/8366 | entropy=2.90 | sn=0.166
# Fractal 686/8366 | entropy=3.27 | sn=0.181
# Fractal 687/8366 | entropy=3.04 | sn=0.172
# Fractal 688/8366 | entropy=3.04 | sn=0.171
# Fractal 689/8366 | entropy=3.01 | sn=0.171
# Fractal 690/8366 | entropy=1.93 | sn=0.127
# Fractal 691/8366 | entropy=1.69 | sn=0.118
# Fractal 692/8366 | entropy=2.81 | sn=0.162
# Fractal 693/8366 | entropy=3.02 | sn=0.171
# Fractal 694/8366 | entropy=3.26 | sn=0.180
# Fractal 695/8366 | entropy=3.06 | sn=0.172
# Fractal 696/8366 | entropy=2.81 | sn=0.162
# Fractal 697/8366 | entropy=3.12 | sn=0.175
# Fractal 698/8366 | entropy=3.22 | sn=0.179
# Fractal 699/8366 | entropy=3.10 | sn=0.174
# Fractal 700/8366 | entropy=2.90 | sn=0.166
# Fractal 701/8366 | entropy=2.98 | sn=0.169
# Fractal 702/8366 | entropy=2.87 | sn=0.165
# Fractal 703/8366 | entropy=2.93 | sn=0.167
# Fractal 704/8366 | entropy=2.45 | sn=0.148
# Fractal 705/8366 | entropy=1.45 | sn=0.108
# Fractal 706/8366 | entropy=2.79 | sn=0.161
# Fractal 707/8366 | entropy=2.95 | sn=0.168
# Fractal 708/8366 | entropy=3.15 | sn=0.176
# Fractal 709/8366 | entropy=3.04 | sn=0.172
# Fractal 710/8366 | entropy=3.07 | sn=0.173
# Fractal 711/8366 | entropy=3.06 | sn=0.173
# Fractal 712/8366 | entropy=3.15 | sn=0.176
# Fractal 713/8366 | entropy=3.24 | sn=0.180
# Fractal 714/8366 | entropy=3.06 | sn=0.173
# Fractal 715/8366 | entropy=3.09 | sn=0.174
# Fractal 716/8366 | entropy=3.12 | sn=0.175
# Fractal 717/8366 | entropy=3.13 | sn=0.175
# Fractal 718/8366 | entropy=2.95 | sn=0.168
# Fractal 719/8366 | entropy=3.02 | sn=0.171
# Fractal 720/8366 | entropy=3.21 | sn=0.179
# Fractal 721/8366 | entropy=3.05 | sn=0.172
# Fractal 722/8366 | entropy=2.81 | sn=0.162
# Fractal 723/8366 | entropy=2.92 | sn=0.167
# Fractal 724/8366 | entropy=2.93 | sn=0.167
# Fractal 725/8366 | entropy=2.75 | sn=0.160
# Fractal 726/8366 | entropy=3.22 | sn=0.179
# Fractal 727/8366 | entropy=3.26 | sn=0.180
# Fractal 728/8366 | entropy=3.21 | sn=0.179
# Fractal 729/8366 | entropy=3.21 | sn=0.178
# Fractal 730/8366 | entropy=3.12 | sn=0.175
# Fractal 731/8366 | entropy=2.98 | sn=0.169
# Fractal 732/8366 | entropy=3.13 | sn=0.175
# Fractal 733/8366 | entropy=3.06 | sn=0.172
# Fractal 734/8366 | entropy=2.96 | sn=0.168
# Fractal 735/8366 | entropy=2.63 | sn=0.155
# Fractal 736/8366 | entropy=2.40 | sn=0.146
# Fractal 737/8366 | entropy=2.90 | sn=0.166
# Fractal 738/8366 | entropy=2.98 | sn=0.169
# Fractal 739/8366 | entropy=3.17 | sn=0.177
# Fractal 740/8366 | entropy=2.99 | sn=0.170
# Fractal 741/8366 | entropy=2.58 | sn=0.153
# Fractal 742/8366 | entropy=3.36 | sn=0.184
# Fractal 743/8366 | entropy=3.17 | sn=0.177
# Fractal 744/8366 | entropy=3.07 | sn=0.173
# Fractal 745/8366 | entropy=2.57 | sn=0.153
# Fractal 746/8366 | entropy=2.44 | sn=0.148
# Fractal 747/8366 | entropy=3.07 | sn=0.173
# Fractal 748/8366 | entropy=2.98 | sn=0.169
# Fractal 749/8366 | entropy=2.86 | sn=0.164
# Fractal 750/8366 | entropy=2.93 | sn=0.167
# Fractal 751/8366 | entropy=3.08 | sn=0.173
# Fractal 752/8366 | entropy=3.24 | sn=0.179
# Fractal 753/8366 | entropy=3.17 | sn=0.177
# Fractal 754/8366 | entropy=3.13 | sn=0.175
# Fractal 755/8366 | entropy=3.26 | sn=0.180
# Fractal 756/8366 | entropy=3.12 | sn=0.175
# Fractal 757/8366 | entropy=3.13 | sn=0.175
# Fractal 758/8366 | entropy=2.97 | sn=0.169
# Fractal 759/8366 | entropy=3.27 | sn=0.181
# Fractal 760/8366 | entropy=2.93 | sn=0.167
# Fractal 761/8366 | entropy=3.05 | sn=0.172
# Fractal 762/8366 | entropy=3.13 | sn=0.175
# Fractal 763/8366 | entropy=3.04 | sn=0.172
# Fractal 764/8366 | entropy=2.96 | sn=0.169
# Fractal 765/8366 | entropy=2.95 | sn=0.168
# Fractal 766/8366 | entropy=3.21 | sn=0.178
# Fractal 767/8366 | entropy=2.99 | sn=0.169
# Fractal 768/8366 | entropy=3.04 | sn=0.172
# Fractal 769/8366 | entropy=2.93 | sn=0.167
# Fractal 770/8366 | entropy=3.13 | sn=0.175
# Fractal 771/8366 | entropy=2.86 | sn=0.165
# Fractal 772/8366 | entropy=3.27 | sn=0.181
# Fractal 773/8366 | entropy=3.08 | sn=0.173
# Fractal 774/8366 | entropy=3.20 | sn=0.178
# Fractal 775/8366 | entropy=2.79 | sn=0.161
# Fractal 776/8366 | entropy=2.92 | sn=0.167
# Fractal 777/8366 | entropy=3.27 | sn=0.181
# Fractal 778/8366 | entropy=3.11 | sn=0.175
# Fractal 779/8366 | entropy=3.09 | sn=0.174
# Fractal 780/8366 | entropy=2.62 | sn=0.155
# Fractal 781/8366 | entropy=1.80 | sn=0.122
# Fractal 782/8366 | entropy=1.91 | sn=0.127
# Fractal 783/8366 | entropy=1.93 | sn=0.127
# Fractal 784/8366 | entropy=1.87 | sn=0.125
# Fractal 785/8366 | entropy=1.73 | sn=0.119
# Fractal 786/8366 | entropy=2.45 | sn=0.148
# Fractal 787/8366 | entropy=3.06 | sn=0.172
# Fractal 788/8366 | entropy=3.29 | sn=0.181
# Fractal 789/8366 | entropy=3.24 | sn=0.180
# Fractal 790/8366 | entropy=3.05 | sn=0.172
# Fractal 791/8366 | entropy=3.07 | sn=0.173
# Fractal 792/8366 | entropy=3.01 | sn=0.171
# Fractal 793/8366 | entropy=3.12 | sn=0.175
# Fractal 794/8366 | entropy=2.95 | sn=0.168
# Fractal 795/8366 | entropy=3.10 | sn=0.174
# Fractal 796/8366 | entropy=3.03 | sn=0.171
# Fractal 797/8366 | entropy=3.12 | sn=0.175
# Fractal 798/8366 | entropy=2.25 | sn=0.140
# Fractal 799/8366 | entropy=2.49 | sn=0.150
# Fractal 800/8366 | entropy=3.27 | sn=0.181
# Fractal 801/8366 | entropy=3.19 | sn=0.178
# Fractal 802/8366 | entropy=3.27 | sn=0.181
# Fractal 803/8366 | entropy=3.15 | sn=0.176
# Fractal 804/8366 | entropy=3.14 | sn=0.176
# Fractal 805/8366 | entropy=2.98 | sn=0.169
# Fractal 806/8366 | entropy=3.29 | sn=0.182
# Fractal 807/8366 | entropy=3.14 | sn=0.175
# Fractal 808/8366 | entropy=3.24 | sn=0.179
# Fractal 809/8366 | entropy=3.06 | sn=0.173
# Fractal 810/8366 | entropy=3.11 | sn=0.174
# Fractal 811/8366 | entropy=3.17 | sn=0.177
# Fractal 812/8366 | entropy=2.90 | sn=0.166
# Fractal 813/8366 | entropy=2.85 | sn=0.164
# Fractal 814/8366 | entropy=3.07 | sn=0.173
# Fractal 815/8366 | entropy=3.06 | sn=0.173
# Fractal 816/8366 | entropy=2.97 | sn=0.169
# Fractal 817/8366 | entropy=2.86 | sn=0.164
# Fractal 818/8366 | entropy=1.82 | sn=0.123
# Fractal 819/8366 | entropy=2.68 | sn=0.157
# Fractal 820/8366 | entropy=3.05 | sn=0.172
# Fractal 821/8366 | entropy=3.05 | sn=0.172
# Fractal 822/8366 | entropy=3.22 | sn=0.179
# Fractal 823/8366 | entropy=3.22 | sn=0.179
# Fractal 824/8366 | entropy=3.12 | sn=0.175
# Fractal 825/8366 | entropy=2.95 | sn=0.168
# Fractal 826/8366 | entropy=2.88 | sn=0.165
# Fractal 827/8366 | entropy=2.94 | sn=0.167
# Fractal 828/8366 | entropy=2.91 | sn=0.166
# Fractal 829/8366 | entropy=2.67 | sn=0.157
# Fractal 830/8366 | entropy=3.11 | sn=0.174
# Fractal 831/8366 | entropy=2.92 | sn=0.167
# Fractal 832/8366 | entropy=3.13 | sn=0.175
# Fractal 833/8366 | entropy=2.79 | sn=0.162
# Fractal 834/8366 | entropy=2.52 | sn=0.151
# Fractal 835/8366 | entropy=3.23 | sn=0.179
# Fractal 836/8366 | entropy=3.34 | sn=0.184
# Fractal 837/8366 | entropy=2.92 | sn=0.167
# Fractal 838/8366 | entropy=3.05 | sn=0.172
# Fractal 839/8366 | entropy=2.45 | sn=0.148
# Fractal 840/8366 | entropy=2.80 | sn=0.162
# Fractal 841/8366 | entropy=3.06 | sn=0.173
# Fractal 842/8366 | entropy=3.09 | sn=0.174
# Fractal 843/8366 | entropy=3.14 | sn=0.176
# Fractal 844/8366 | entropy=3.11 | sn=0.174
# Fractal 845/8366 | entropy=2.45 | sn=0.148
# Fractal 846/8366 | entropy=2.60 | sn=0.154
# Fractal 847/8366 | entropy=3.04 | sn=0.172
# Fractal 848/8366 | entropy=3.11 | sn=0.174
# Fractal 849/8366 | entropy=3.08 | sn=0.173
# Fractal 850/8366 | entropy=3.12 | sn=0.175
# Fractal 851/8366 | entropy=2.99 | sn=0.169
# Fractal 852/8366 | entropy=2.98 | sn=0.169
# Fractal 853/8366 | entropy=2.84 | sn=0.164
# Fractal 854/8366 | entropy=2.93 | sn=0.167
# Fractal 855/8366 | entropy=2.77 | sn=0.161
# Fractal 856/8366 | entropy=2.98 | sn=0.169
# Fractal 857/8366 | entropy=3.12 | sn=0.175
# Fractal 858/8366 | entropy=2.98 | sn=0.169
# Fractal 859/8366 | entropy=3.10 | sn=0.174
# Fractal 860/8366 | entropy=3.13 | sn=0.175
# Fractal 861/8366 | entropy=2.92 | sn=0.167
# Fractal 862/8366 | entropy=3.09 | sn=0.174
# Fractal 863/8366 | entropy=3.10 | sn=0.174
# Fractal 864/8366 | entropy=3.04 | sn=0.172
# Fractal 865/8366 | entropy=2.93 | sn=0.167
# Fractal 866/8366 | entropy=3.04 | sn=0.172
# Fractal 867/8366 | entropy=2.95 | sn=0.168
# Fractal 868/8366 | entropy=2.69 | sn=0.158
# Fractal 869/8366 | entropy=2.39 | sn=0.146
# Fractal 870/8366 | entropy=2.94 | sn=0.168
# Fractal 871/8366 | entropy=3.08 | sn=0.173
# Fractal 872/8366 | entropy=3.08 | sn=0.173
# Fractal 873/8366 | entropy=2.83 | sn=0.163
# Fractal 874/8366 | entropy=1.35 | sn=0.104
# Fractal 875/8366 | entropy=0.15 | sn=0.056
# Fractal 876/8366 | entropy=1.41 | sn=0.106
# Fractal 877/8366 | entropy=1.41 | sn=0.106
# Fractal 878/8366 | entropy=2.69 | sn=0.158
# Fractal 879/8366 | entropy=2.46 | sn=0.148
# Fractal 880/8366 | entropy=2.88 | sn=0.165
# Fractal 881/8366 | entropy=3.09 | sn=0.174
# Fractal 882/8366 | entropy=3.21 | sn=0.178
# Fractal 883/8366 | entropy=3.12 | sn=0.175
# Fractal 884/8366 | entropy=3.22 | sn=0.179
# Fractal 885/8366 | entropy=2.75 | sn=0.160
# Fractal 886/8366 | entropy=2.90 | sn=0.166
# Fractal 887/8366 | entropy=2.82 | sn=0.163
# Fractal 888/8366 | entropy=2.96 | sn=0.168
# Fractal 889/8366 | entropy=3.12 | sn=0.175
# Fractal 890/8366 | entropy=3.10 | sn=0.174
# Fractal 891/8366 | entropy=2.31 | sn=0.142
# Fractal 892/8366 | entropy=1.74 | sn=0.120
# Fractal 893/8366 | entropy=3.12 | sn=0.175
# Fractal 894/8366 | entropy=3.26 | sn=0.180
# Fractal 895/8366 | entropy=3.15 | sn=0.176
# Fractal 896/8366 | entropy=3.27 | sn=0.181
# Fractal 897/8366 | entropy=3.17 | sn=0.177
# Fractal 898/8366 | entropy=2.88 | sn=0.165
# Fractal 899/8366 | entropy=2.65 | sn=0.156
# Fractal 900/8366 | entropy=3.10 | sn=0.174
# Fractal 901/8366 | entropy=3.42 | sn=0.187
# Fractal 902/8366 | entropy=3.29 | sn=0.182
# Fractal 903/8366 | entropy=3.19 | sn=0.178
# Fractal 904/8366 | entropy=3.10 | sn=0.174
# Fractal 905/8366 | entropy=3.17 | sn=0.177
# Fractal 906/8366 | entropy=3.29 | sn=0.182
# Fractal 907/8366 | entropy=3.12 | sn=0.175
# Fractal 908/8366 | entropy=3.06 | sn=0.173
# Fractal 909/8366 | entropy=3.21 | sn=0.178
# Fractal 910/8366 | entropy=3.01 | sn=0.170
# Fractal 911/8366 | entropy=2.84 | sn=0.164
# Fractal 912/8366 | entropy=2.35 | sn=0.144
# Fractal 913/8366 | entropy=2.57 | sn=0.153
# Fractal 914/8366 | entropy=2.94 | sn=0.167
# Fractal 915/8366 | entropy=3.08 | sn=0.173
# Fractal 916/8366 | entropy=3.31 | sn=0.182
# Fractal 917/8366 | entropy=2.92 | sn=0.167
# Fractal 918/8366 | entropy=2.96 | sn=0.168
# Fractal 919/8366 | entropy=2.88 | sn=0.165
# Fractal 920/8366 | entropy=3.08 | sn=0.173
# Fractal 921/8366 | entropy=3.16 | sn=0.176
# Fractal 922/8366 | entropy=3.06 | sn=0.172
# Fractal 923/8366 | entropy=3.03 | sn=0.171
# Fractal 924/8366 | entropy=3.14 | sn=0.175
# Fractal 925/8366 | entropy=2.46 | sn=0.149
# Fractal 926/8366 | entropy=1.57 | sn=0.113
# Fractal 927/8366 | entropy=0.81 | sn=0.082
# Fractal 928/8366 | entropy=1.67 | sn=0.117
# Fractal 929/8366 | entropy=3.16 | sn=0.176
# Fractal 930/8366 | entropy=3.29 | sn=0.182
# Fractal 931/8366 | entropy=2.97 | sn=0.169
# Fractal 932/8366 | entropy=3.09 | sn=0.174
# Fractal 933/8366 | entropy=2.77 | sn=0.161
# Fractal 934/8366 | entropy=2.78 | sn=0.161
# Fractal 935/8366 | entropy=3.11 | sn=0.174
# Fractal 936/8366 | entropy=3.03 | sn=0.171
# Fractal 937/8366 | entropy=2.88 | sn=0.165
# Fractal 938/8366 | entropy=2.54 | sn=0.152
# Fractal 939/8366 | entropy=0.75 | sn=0.080
# Fractal 940/8366 | entropy=2.29 | sn=0.142
# Fractal 941/8366 | entropy=2.92 | sn=0.167
# Fractal 942/8366 | entropy=3.09 | sn=0.174
# Fractal 943/8366 | entropy=3.08 | sn=0.173
# Fractal 944/8366 | entropy=3.03 | sn=0.171
# Fractal 945/8366 | entropy=2.91 | sn=0.166
# Fractal 946/8366 | entropy=2.75 | sn=0.160
# Fractal 947/8366 | entropy=3.06 | sn=0.172
# Fractal 948/8366 | entropy=2.97 | sn=0.169
# Fractal 949/8366 | entropy=2.93 | sn=0.167
# Fractal 950/8366 | entropy=2.90 | sn=0.166
# Fractal 951/8366 | entropy=2.90 | sn=0.166
# Fractal 952/8366 | entropy=2.92 | sn=0.167
# Fractal 953/8366 | entropy=3.08 | sn=0.173
# Fractal 954/8366 | entropy=3.22 | sn=0.179
# Fractal 955/8366 | entropy=2.89 | sn=0.165
# Fractal 956/8366 | entropy=2.98 | sn=0.169
# Fractal 957/8366 | entropy=2.82 | sn=0.163
# Fractal 958/8366 | entropy=3.04 | sn=0.171
# Fractal 959/8366 | entropy=3.12 | sn=0.175
# Fractal 960/8366 | entropy=3.13 | sn=0.175
# Fractal 961/8366 | entropy=2.61 | sn=0.154
# Fractal 962/8366 | entropy=0.85 | sn=0.084
# Fractal 963/8366 | entropy=1.48 | sn=0.109
# Fractal 964/8366 | entropy=2.93 | sn=0.167
# Fractal 965/8366 | entropy=3.09 | sn=0.173
# Fractal 966/8366 | entropy=3.09 | sn=0.174
# Fractal 967/8366 | entropy=2.07 | sn=0.133
# Fractal 968/8366 | entropy=1.02 | sn=0.091
# Fractal 969/8366 | entropy=1.08 | sn=0.093
# Fractal 970/8366 | entropy=3.08 | sn=0.173
# Fractal 971/8366 | entropy=2.68 | sn=0.157
# Fractal 972/8366 | entropy=3.15 | sn=0.176
# Fractal 973/8366 | entropy=3.21 | sn=0.178
# Fractal 974/8366 | entropy=3.23 | sn=0.179
# Fractal 975/8366 | entropy=3.08 | sn=0.173
# Fractal 976/8366 | entropy=2.68 | sn=0.157
# Fractal 977/8366 | entropy=2.94 | sn=0.168
# Fractal 978/8366 | entropy=3.10 | sn=0.174
# Fractal 979/8366 | entropy=2.67 | sn=0.157
# Fractal 980/8366 | entropy=3.01 | sn=0.171
# Fractal 981/8366 | entropy=3.03 | sn=0.171
# Fractal 982/8366 | entropy=3.05 | sn=0.172
# Fractal 983/8366 | entropy=2.96 | sn=0.168
# Fractal 984/8366 | entropy=2.66 | sn=0.156
# Fractal 985/8366 | entropy=1.77 | sn=0.121
# Fractal 986/8366 | entropy=2.59 | sn=0.154
# Fractal 987/8366 | entropy=3.16 | sn=0.176
# Fractal 988/8366 | entropy=3.23 | sn=0.179
# Fractal 989/8366 | entropy=3.02 | sn=0.171
# Fractal 990/8366 | entropy=3.09 | sn=0.174
# Fractal 991/8366 | entropy=3.26 | sn=0.180
# Fractal 992/8366 | entropy=3.02 | sn=0.171
# Fractal 993/8366 | entropy=2.78 | sn=0.161
# Fractal 994/8366 | entropy=3.22 | sn=0.179
# Fractal 995/8366 | entropy=3.19 | sn=0.177
# Fractal 996/8366 | entropy=3.24 | sn=0.180
# Fractal 997/8366 | entropy=2.91 | sn=0.167
# Fractal 998/8366 | entropy=2.80 | sn=0.162
# Fractal 999/8366 | entropy=3.10 | sn=0.174
# Fractal 1000/8366 | entropy=3.12 | sn=0.175
# Fractal 1001/8366 | entropy=3.12 | sn=0.175
# Fractal 1002/8366 | entropy=3.00 | sn=0.170
# Fractal 1003/8366 | entropy=2.87 | sn=0.165
# Fractal 1004/8366 | entropy=1.39 | sn=0.106
# Fractal 1005/8366 | entropy=1.36 | sn=0.104
# Fractal 1006/8366 | entropy=2.28 | sn=0.141
# Fractal 1007/8366 | entropy=3.02 | sn=0.171
# Fractal 1008/8366 | entropy=3.02 | sn=0.171
# Fractal 1009/8366 | entropy=2.93 | sn=0.167
# Fractal 1010/8366 | entropy=3.15 | sn=0.176
# Fractal 1011/8366 | entropy=3.16 | sn=0.176
# Fractal 1012/8366 | entropy=3.01 | sn=0.170
# Fractal 1013/8366 | entropy=2.75 | sn=0.160
# Fractal 1014/8366 | entropy=2.81 | sn=0.163
# Fractal 1015/8366 | entropy=2.70 | sn=0.158
# Fractal 1016/8366 | entropy=3.13 | sn=0.175
# Fractal 1017/8366 | entropy=2.73 | sn=0.159
# Fractal 1018/8366 | entropy=1.47 | sn=0.109
# Fractal 1019/8366 | entropy=0.49 | sn=0.070
# Fractal 1020/8366 | entropy=0.94 | sn=0.088
# Fractal 1021/8366 | entropy=2.23 | sn=0.139
# Fractal 1022/8366 | entropy=3.23 | sn=0.179
# Fractal 1023/8366 | entropy=3.34 | sn=0.183
# Fractal 1024/8366 | entropy=3.12 | sn=0.175
# Fractal 1025/8366 | entropy=3.01 | sn=0.170
# Fractal 1026/8366 | entropy=2.94 | sn=0.167
# Fractal 1027/8366 | entropy=2.90 | sn=0.166
# Fractal 1028/8366 | entropy=3.05 | sn=0.172
# Fractal 1029/8366 | entropy=2.93 | sn=0.167
# Fractal 1030/8366 | entropy=3.16 | sn=0.176
# Fractal 1031/8366 | entropy=3.08 | sn=0.173
# Fractal 1032/8366 | entropy=1.94 | sn=0.128
# Fractal 1033/8366 | entropy=1.07 | sn=0.093
# Fractal 1034/8366 | entropy=2.87 | sn=0.165
# Fractal 1035/8366 | entropy=2.54 | sn=0.152
# Fractal 1036/8366 | entropy=2.54 | sn=0.152
# Fractal 1037/8366 | entropy=2.76 | sn=0.161
# Fractal 1038/8366 | entropy=2.48 | sn=0.149
# Fractal 1039/8366 | entropy=2.49 | sn=0.150
# Fractal 1040/8366 | entropy=2.56 | sn=0.152
# Fractal 1041/8366 | entropy=3.13 | sn=0.175
# Fractal 1042/8366 | entropy=2.95 | sn=0.168
# Fractal 1043/8366 | entropy=2.77 | sn=0.161
# Fractal 1044/8366 | entropy=3.10 | sn=0.174
# Fractal 1045/8366 | entropy=3.12 | sn=0.175
# Fractal 1046/8366 | entropy=3.16 | sn=0.177
# Fractal 1047/8366 | entropy=3.16 | sn=0.176
# Fractal 1048/8366 | entropy=3.21 | sn=0.178
# Fractal 1049/8366 | entropy=3.00 | sn=0.170
# Fractal 1050/8366 | entropy=3.03 | sn=0.171
# Fractal 1051/8366 | entropy=3.21 | sn=0.179
# Fractal 1052/8366 | entropy=3.19 | sn=0.177
# Fractal 1053/8366 | entropy=3.19 | sn=0.178
# Fractal 1054/8366 | entropy=3.12 | sn=0.175
# Fractal 1055/8366 | entropy=2.33 | sn=0.143
# Fractal 1056/8366 | entropy=1.27 | sn=0.101
# Fractal 1057/8366 | entropy=2.01 | sn=0.130
# Fractal 1058/8366 | entropy=2.94 | sn=0.168
# Fractal 1059/8366 | entropy=2.94 | sn=0.168
# Fractal 1060/8366 | entropy=2.92 | sn=0.167
# Fractal 1061/8366 | entropy=2.76 | sn=0.161
# Fractal 1062/8366 | entropy=2.54 | sn=0.152
# Fractal 1063/8366 | entropy=2.63 | sn=0.155
# Fractal 1064/8366 | entropy=3.27 | sn=0.181
# Fractal 1065/8366 | entropy=3.08 | sn=0.173
# Fractal 1066/8366 | entropy=3.03 | sn=0.171
# Fractal 1067/8366 | entropy=3.17 | sn=0.177
# Fractal 1068/8366 | entropy=2.94 | sn=0.168
# Fractal 1069/8366 | entropy=3.13 | sn=0.175
# Fractal 1070/8366 | entropy=2.99 | sn=0.170
# Fractal 1071/8366 | entropy=3.21 | sn=0.178
# Fractal 1072/8366 | entropy=2.90 | sn=0.166
# Fractal 1073/8366 | entropy=2.29 | sn=0.142
# Fractal 1074/8366 | entropy=3.16 | sn=0.176
# Fractal 1075/8366 | entropy=3.17 | sn=0.177
# Fractal 1076/8366 | entropy=3.20 | sn=0.178
# Fractal 1077/8366 | entropy=3.09 | sn=0.174
# Fractal 1078/8366 | entropy=2.72 | sn=0.159
# Fractal 1079/8366 | entropy=2.74 | sn=0.160
# Fractal 1080/8366 | entropy=3.24 | sn=0.179
# Fractal 1081/8366 | entropy=3.03 | sn=0.171
# Fractal 1082/8366 | entropy=3.06 | sn=0.172
# Fractal 1083/8366 | entropy=3.01 | sn=0.170
# Fractal 1084/8366 | entropy=3.06 | sn=0.173
# Fractal 1085/8366 | entropy=3.24 | sn=0.179
# Fractal 1086/8366 | entropy=3.03 | sn=0.171
# Fractal 1087/8366 | entropy=2.91 | sn=0.166
# Fractal 1088/8366 | entropy=3.11 | sn=0.174
# Fractal 1089/8366 | entropy=2.89 | sn=0.166
# Fractal 1090/8366 | entropy=3.00 | sn=0.170
# Fractal 1091/8366 | entropy=3.03 | sn=0.171
# Fractal 1092/8366 | entropy=3.14 | sn=0.176
# Fractal 1093/8366 | entropy=3.08 | sn=0.173
# Fractal 1094/8366 | entropy=2.77 | sn=0.161
# Fractal 1095/8366 | entropy=2.85 | sn=0.164
# Fractal 1096/8366 | entropy=2.99 | sn=0.169
# Fractal 1097/8366 | entropy=1.45 | sn=0.108
# Fractal 1098/8366 | entropy=0.91 | sn=0.086
# Fractal 1099/8366 | entropy=2.54 | sn=0.152
# Fractal 1100/8366 | entropy=2.82 | sn=0.163
# Fractal 1101/8366 | entropy=2.97 | sn=0.169
# Fractal 1102/8366 | entropy=3.04 | sn=0.172
# Fractal 1103/8366 | entropy=3.03 | sn=0.171
# Fractal 1104/8366 | entropy=3.15 | sn=0.176
# Fractal 1105/8366 | entropy=2.92 | sn=0.167
# Fractal 1106/8366 | entropy=2.94 | sn=0.168
# Fractal 1107/8366 | entropy=3.10 | sn=0.174
# Fractal 1108/8366 | entropy=3.14 | sn=0.176
# Fractal 1109/8366 | entropy=2.93 | sn=0.167
# Fractal 1110/8366 | entropy=3.02 | sn=0.171
# Fractal 1111/8366 | entropy=2.33 | sn=0.143
# Fractal 1112/8366 | entropy=1.87 | sn=0.125
# Fractal 1113/8366 | entropy=1.59 | sn=0.114
# Fractal 1114/8366 | entropy=2.76 | sn=0.160
# Fractal 1115/8366 | entropy=3.03 | sn=0.171
# ...
# Fractal 8005/8366 | entropy=2.86 | sn=0.164
# Fractal 8006/8366 | entropy=2.88 | sn=0.165
# Fractal 8007/8366 | entropy=2.28 | sn=0.141
# Fractal 8008/8366 | entropy=2.61 | sn=0.154
# Fractal 8009/8366 | entropy=3.13 | sn=0.175
# Fractal 8010/8366 | entropy=2.96 | sn=0.168
# Fractal 8011/8366 | entropy=3.09 | sn=0.174
# Fractal 8012/8366 | entropy=2.87 | sn=0.165
# Fractal 8013/8366 | entropy=2.30 | sn=0.142
# Fractal 8014/8366 | entropy=0.33 | sn=0.063
# Fractal 8015/8366 | entropy=1.95 | sn=0.128
# Fractal 8016/8366 | entropy=2.96 | sn=0.168
# Fractal 8017/8366 | entropy=3.11 | sn=0.174
# Fractal 8018/8366 | entropy=2.75 | sn=0.160
# Fractal 8019/8366 | entropy=2.18 | sn=0.137
# Fractal 8020/8366 | entropy=2.96 | sn=0.168
# Fractal 8021/8366 | entropy=2.63 | sn=0.155
# Fractal 8022/8366 | entropy=1.25 | sn=0.100
# Fractal 8023/8366 | entropy=1.05 | sn=0.092
# Fractal 8024/8366 | entropy=2.67 | sn=0.157
# Fractal 8025/8366 | entropy=3.11 | sn=0.174
# Fractal 8026/8366 | entropy=2.96 | sn=0.168
# Fractal 8027/8366 | entropy=2.86 | sn=0.164
# Fractal 8028/8366 | entropy=2.99 | sn=0.170
# Fractal 8029/8366 | entropy=2.56 | sn=0.152
# Fractal 8030/8366 | entropy=2.19 | sn=0.138
# Fractal 8031/8366 | entropy=3.13 | sn=0.175
# Fractal 8032/8366 | entropy=2.85 | sn=0.164
# Fractal 8033/8366 | entropy=3.06 | sn=0.172
# Fractal 8034/8366 | entropy=3.09 | sn=0.174
# Fractal 8035/8366 | entropy=2.41 | sn=0.146
# Fractal 8036/8366 | entropy=2.70 | sn=0.158
# Fractal 8037/8366 | entropy=2.64 | sn=0.156
# Fractal 8038/8366 | entropy=2.57 | sn=0.153
# Fractal 8039/8366 | entropy=0.46 | sn=0.069
# Fractal 8040/8366 | entropy=0.15 | sn=0.056
# Fractal 8041/8366 | entropy=2.02 | sn=0.131
# Fractal 8042/8366 | entropy=2.98 | sn=0.169
# Fractal 8043/8366 | entropy=2.97 | sn=0.169
# Fractal 8044/8366 | entropy=2.69 | sn=0.158
# Fractal 8045/8366 | entropy=3.13 | sn=0.175
# Fractal 8046/8366 | entropy=2.89 | sn=0.166
# Fractal 8047/8366 | entropy=3.14 | sn=0.176
# Fractal 8048/8366 | entropy=2.95 | sn=0.168
# Fractal 8049/8366 | entropy=3.13 | sn=0.175
# Fractal 8050/8366 | entropy=2.96 | sn=0.168
# Fractal 8051/8366 | entropy=3.19 | sn=0.178
# Fractal 8052/8366 | entropy=3.14 | sn=0.175
# Fractal 8053/8366 | entropy=3.21 | sn=0.178
# Fractal 8054/8366 | entropy=3.13 | sn=0.175
# Fractal 8055/8366 | entropy=3.15 | sn=0.176
# Fractal 8056/8366 | entropy=3.10 | sn=0.174
# Fractal 8057/8366 | entropy=2.18 | sn=0.137
# Fractal 8058/8366 | entropy=2.84 | sn=0.164
# Fractal 8059/8366 | entropy=2.75 | sn=0.160
# Fractal 8060/8366 | entropy=3.13 | sn=0.175
# Fractal 8061/8366 | entropy=3.05 | sn=0.172
# Fractal 8062/8366 | entropy=3.16 | sn=0.176
# Fractal 8063/8366 | entropy=3.01 | sn=0.170
# Fractal 8064/8366 | entropy=2.50 | sn=0.150
# Fractal 8065/8366 | entropy=2.42 | sn=0.147
# Fractal 8066/8366 | entropy=2.90 | sn=0.166
# Fractal 8067/8366 | entropy=3.09 | sn=0.174
# Fractal 8068/8366 | entropy=3.31 | sn=0.182
# Fractal 8069/8366 | entropy=3.08 | sn=0.173
# Fractal 8070/8366 | entropy=2.26 | sn=0.141
# Fractal 8071/8366 | entropy=2.94 | sn=0.168
# Fractal 8072/8366 | entropy=2.97 | sn=0.169
# Fractal 8073/8366 | entropy=2.37 | sn=0.145
# Fractal 8074/8366 | entropy=1.69 | sn=0.117
# Fractal 8075/8366 | entropy=1.44 | sn=0.108
# Fractal 8076/8366 | entropy=2.29 | sn=0.141
# Fractal 8077/8366 | entropy=3.22 | sn=0.179
# Fractal 8078/8366 | entropy=2.95 | sn=0.168
# Fractal 8079/8366 | entropy=3.17 | sn=0.177
# Fractal 8080/8366 | entropy=3.00 | sn=0.170
# Fractal 8081/8366 | entropy=3.21 | sn=0.179
# Fractal 8082/8366 | entropy=3.24 | sn=0.180
# Fractal 8083/8366 | entropy=3.17 | sn=0.177
# Fractal 8084/8366 | entropy=3.12 | sn=0.175
# Fractal 8085/8366 | entropy=0.43 | sn=0.067
# Fractal 8086/8366 | entropy=0.52 | sn=0.071
# Fractal 8087/8366 | entropy=0.00 | sn=0.050
# Fractal 8088/8366 | entropy=0.00 | sn=0.050
# Fractal 8089/8366 | entropy=0.00 | sn=0.050
# Fractal 8090/8366 | entropy=0.15 | sn=0.056
# Fractal 8091/8366 | entropy=1.78 | sn=0.121
# Fractal 8092/8366 | entropy=2.90 | sn=0.166
# Fractal 8093/8366 | entropy=2.96 | sn=0.169
# Fractal 8094/8366 | entropy=2.70 | sn=0.158
# Fractal 8095/8366 | entropy=2.53 | sn=0.151
# Fractal 8096/8366 | entropy=2.99 | sn=0.170
# Fractal 8097/8366 | entropy=3.20 | sn=0.178
# Fractal 8098/8366 | entropy=3.09 | sn=0.173
# Fractal 8099/8366 | entropy=3.06 | sn=0.173
# Fractal 8100/8366 | entropy=3.07 | sn=0.173
# Fractal 8101/8366 | entropy=2.64 | sn=0.156
# Fractal 8102/8366 | entropy=2.85 | sn=0.164
# Fractal 8103/8366 | entropy=2.98 | sn=0.169
# Fractal 8104/8366 | entropy=2.72 | sn=0.159
# Fractal 8105/8366 | entropy=3.10 | sn=0.174
# Fractal 8106/8366 | entropy=3.00 | sn=0.170
# Fractal 8107/8366 | entropy=2.47 | sn=0.149
# Fractal 8108/8366 | entropy=1.21 | sn=0.098
# Fractal 8109/8366 | entropy=2.92 | sn=0.167
# Fractal 8110/8366 | entropy=3.10 | sn=0.174
# Fractal 8111/8366 | entropy=2.76 | sn=0.160
# Fractal 8112/8366 | entropy=0.97 | sn=0.089
# Fractal 8113/8366 | entropy=0.30 | sn=0.062
# Fractal 8114/8366 | entropy=0.99 | sn=0.090
# Fractal 8115/8366 | entropy=0.59 | sn=0.074
# Fractal 8116/8366 | entropy=0.80 | sn=0.082
# Fractal 8117/8366 | entropy=2.75 | sn=0.160
# Fractal 8118/8366 | entropy=2.93 | sn=0.167
# Fractal 8119/8366 | entropy=3.11 | sn=0.174
# Fractal 8120/8366 | entropy=2.94 | sn=0.168
# Fractal 8121/8366 | entropy=3.22 | sn=0.179
# Fractal 8122/8366 | entropy=2.99 | sn=0.170
# Fractal 8123/8366 | entropy=2.06 | sn=0.132
# Fractal 8124/8366 | entropy=2.55 | sn=0.152
# Fractal 8125/8366 | entropy=3.11 | sn=0.174
# Fractal 8126/8366 | entropy=3.10 | sn=0.174
# Fractal 8127/8366 | entropy=2.99 | sn=0.170
# Fractal 8128/8366 | entropy=3.14 | sn=0.175
# Fractal 8129/8366 | entropy=2.54 | sn=0.152
# Fractal 8130/8366 | entropy=2.96 | sn=0.168
# Fractal 8131/8366 | entropy=2.99 | sn=0.170
# Fractal 8132/8366 | entropy=2.28 | sn=0.141
# Fractal 8133/8366 | entropy=0.00 | sn=0.050
# Fractal 8134/8366 | entropy=0.58 | sn=0.073
# Fractal 8135/8366 | entropy=2.56 | sn=0.153
# Fractal 8136/8366 | entropy=2.69 | sn=0.157
# Fractal 8137/8366 | entropy=2.83 | sn=0.163
# Fractal 8138/8366 | entropy=2.91 | sn=0.167
# Fractal 8139/8366 | entropy=3.02 | sn=0.171
# Fractal 8140/8366 | entropy=1.90 | sn=0.126
# Fractal 8141/8366 | entropy=1.91 | sn=0.127
# Fractal 8142/8366 | entropy=2.40 | sn=0.146
# Fractal 8143/8366 | entropy=2.77 | sn=0.161
# Fractal 8144/8366 | entropy=2.75 | sn=0.160
# Fractal 8145/8366 | entropy=3.18 | sn=0.177
# Fractal 8146/8366 | entropy=3.06 | sn=0.173
# Fractal 8147/8366 | entropy=3.25 | sn=0.180
# Fractal 8148/8366 | entropy=3.10 | sn=0.174
# Fractal 8149/8366 | entropy=2.94 | sn=0.168
# Fractal 8150/8366 | entropy=1.56 | sn=0.113
# Fractal 8151/8366 | entropy=1.39 | sn=0.106
# Fractal 8152/8366 | entropy=3.04 | sn=0.172
# Fractal 8153/8366 | entropy=3.17 | sn=0.177
# Fractal 8154/8366 | entropy=3.12 | sn=0.175
# Fractal 8155/8366 | entropy=3.12 | sn=0.175
# Fractal 8156/8366 | entropy=1.78 | sn=0.121
# Fractal 8157/8366 | entropy=0.83 | sn=0.083
# Fractal 8158/8366 | entropy=0.15 | sn=0.056
# Fractal 8159/8366 | entropy=0.00 | sn=0.050
# Fractal 8160/8366 | entropy=1.84 | sn=0.124
# Fractal 8161/8366 | entropy=3.21 | sn=0.178
# Fractal 8162/8366 | entropy=3.12 | sn=0.175
# Fractal 8163/8366 | entropy=3.13 | sn=0.175
# Fractal 8164/8366 | entropy=2.98 | sn=0.169
# Fractal 8165/8366 | entropy=2.95 | sn=0.168
# Fractal 8166/8366 | entropy=2.36 | sn=0.144
# Fractal 8167/8366 | entropy=1.62 | sn=0.115
# Fractal 8168/8366 | entropy=1.86 | sn=0.124
# Fractal 8169/8366 | entropy=1.82 | sn=0.123
# Fractal 8170/8366 | entropy=2.70 | sn=0.158
# Fractal 8171/8366 | entropy=3.03 | sn=0.171
# Fractal 8172/8366 | entropy=2.91 | sn=0.166
# Fractal 8173/8366 | entropy=3.21 | sn=0.178
# Fractal 8174/8366 | entropy=3.13 | sn=0.175
# Fractal 8175/8366 | entropy=3.01 | sn=0.170
# Fractal 8176/8366 | entropy=3.25 | sn=0.180
# Fractal 8177/8366 | entropy=3.27 | sn=0.181
# Fractal 8178/8366 | entropy=3.20 | sn=0.178
# Fractal 8179/8366 | entropy=0.83 | sn=0.083
# Fractal 8180/8366 | entropy=0.88 | sn=0.085
# Fractal 8181/8366 | entropy=0.19 | sn=0.057
# Fractal 8182/8366 | entropy=0.15 | sn=0.056
# Fractal 8183/8366 | entropy=0.15 | sn=0.056
# Fractal 8184/8366 | entropy=1.26 | sn=0.100
# Fractal 8185/8366 | entropy=2.13 | sn=0.135
# Fractal 8186/8366 | entropy=2.28 | sn=0.141
# Fractal 8187/8366 | entropy=2.43 | sn=0.147
# Fractal 8188/8366 | entropy=3.07 | sn=0.173
# Fractal 8189/8366 | entropy=3.08 | sn=0.173
# Fractal 8190/8366 | entropy=3.10 | sn=0.174
# Fractal 8191/8366 | entropy=3.22 | sn=0.179
# Fractal 8192/8366 | entropy=3.06 | sn=0.172
# Fractal 8193/8366 | entropy=3.07 | sn=0.173
# Fractal 8194/8366 | entropy=2.60 | sn=0.154
# Fractal 8195/8366 | entropy=1.74 | sn=0.119
# Fractal 8196/8366 | entropy=2.01 | sn=0.130
# Fractal 8197/8366 | entropy=2.81 | sn=0.163
# Fractal 8198/8366 | entropy=3.00 | sn=0.170
# Fractal 8199/8366 | entropy=3.10 | sn=0.174
# Fractal 8200/8366 | entropy=3.07 | sn=0.173
# Fractal 8201/8366 | entropy=2.17 | sn=0.137
# Fractal 8202/8366 | entropy=2.02 | sn=0.131
# Fractal 8203/8366 | entropy=2.94 | sn=0.168
# Fractal 8204/8366 | entropy=3.13 | sn=0.175
# Fractal 8205/8366 | entropy=3.22 | sn=0.179
# Fractal 8206/8366 | entropy=2.46 | sn=0.148
# Fractal 8207/8366 | entropy=2.12 | sn=0.135
# Fractal 8208/8366 | entropy=1.75 | sn=0.120
# Fractal 8209/8366 | entropy=1.23 | sn=0.099
# Fractal 8210/8366 | entropy=2.43 | sn=0.147
# Fractal 8211/8366 | entropy=3.00 | sn=0.170
# Fractal 8212/8366 | entropy=3.02 | sn=0.171
# Fractal 8213/8366 | entropy=3.07 | sn=0.173
# Fractal 8214/8366 | entropy=2.89 | sn=0.165
# Fractal 8215/8366 | entropy=2.73 | sn=0.159
# Fractal 8216/8366 | entropy=2.12 | sn=0.135
# Fractal 8217/8366 | entropy=0.93 | sn=0.087
# Fractal 8218/8366 | entropy=2.85 | sn=0.164
# Fractal 8219/8366 | entropy=3.04 | sn=0.172
# Fractal 8220/8366 | entropy=3.04 | sn=0.172
# Fractal 8221/8366 | entropy=3.06 | sn=0.173
# Fractal 8222/8366 | entropy=3.16 | sn=0.176
# Fractal 8223/8366 | entropy=2.62 | sn=0.155
# Fractal 8224/8366 | entropy=2.74 | sn=0.159
# Fractal 8225/8366 | entropy=2.89 | sn=0.165
# Fractal 8226/8366 | entropy=2.38 | sn=0.145
# Fractal 8227/8366 | entropy=0.21 | sn=0.059
# Fractal 8228/8366 | entropy=1.05 | sn=0.092
# Fractal 8229/8366 | entropy=2.84 | sn=0.164
# Fractal 8230/8366 | entropy=2.71 | sn=0.158
# Fractal 8231/8366 | entropy=2.64 | sn=0.155
# Fractal 8232/8366 | entropy=2.54 | sn=0.151
# Fractal 8233/8366 | entropy=2.12 | sn=0.135
# Fractal 8234/8366 | entropy=0.33 | sn=0.063
# Fractal 8235/8366 | entropy=1.03 | sn=0.091
# Fractal 8236/8366 | entropy=0.74 | sn=0.079
# Fractal 8237/8366 | entropy=2.01 | sn=0.130
# Fractal 8238/8366 | entropy=2.94 | sn=0.168
# Fractal 8239/8366 | entropy=3.06 | sn=0.173
# Fractal 8240/8366 | entropy=1.65 | sn=0.116
# Fractal 8241/8366 | entropy=2.78 | sn=0.161
# Fractal 8242/8366 | entropy=3.13 | sn=0.175
# Fractal 8243/8366 | entropy=2.92 | sn=0.167
# Fractal 8244/8366 | entropy=0.80 | sn=0.082
# Fractal 8245/8366 | entropy=2.08 | sn=0.133
# Fractal 8246/8366 | entropy=3.10 | sn=0.174
# Fractal 8247/8366 | entropy=3.12 | sn=0.175
# Fractal 8248/8366 | entropy=3.12 | sn=0.175
# Fractal 8249/8366 | entropy=2.14 | sn=0.136
# Fractal 8250/8366 | entropy=0.00 | sn=0.050
# Fractal 8251/8366 | entropy=0.00 | sn=0.050
# Fractal 8252/8366 | entropy=0.00 | sn=0.050
# Fractal 8253/8366 | entropy=0.85 | sn=0.084
# Fractal 8254/8366 | entropy=2.87 | sn=0.165
# Fractal 8255/8366 | entropy=3.47 | sn=0.189
# Fractal 8256/8366 | entropy=3.29 | sn=0.182
# Fractal 8257/8366 | entropy=3.04 | sn=0.172
# Fractal 8258/8366 | entropy=2.99 | sn=0.170
# Fractal 8259/8366 | entropy=3.16 | sn=0.176
# Fractal 8260/8366 | entropy=3.02 | sn=0.171
# Fractal 8261/8366 | entropy=3.00 | sn=0.170
# Fractal 8262/8366 | entropy=3.18 | sn=0.177
# Fractal 8263/8366 | entropy=3.13 | sn=0.175
# Fractal 8264/8366 | entropy=2.82 | sn=0.163
# Fractal 8265/8366 | entropy=3.01 | sn=0.171
# Fractal 8266/8366 | entropy=3.17 | sn=0.177
# Fractal 8267/8366 | entropy=3.28 | sn=0.181
# Fractal 8268/8366 | entropy=3.12 | sn=0.175
# Fractal 8269/8366 | entropy=3.07 | sn=0.173
# Fractal 8270/8366 | entropy=2.98 | sn=0.169
# Fractal 8271/8366 | entropy=3.12 | sn=0.175
# Fractal 8272/8366 | entropy=3.16 | sn=0.176
# Fractal 8273/8366 | entropy=0.52 | sn=0.071
# Fractal 8274/8366 | entropy=0.47 | sn=0.069
# Fractal 8275/8366 | entropy=0.43 | sn=0.067
# Fractal 8276/8366 | entropy=0.33 | sn=0.063
# Fractal 8277/8366 | entropy=1.23 | sn=0.099
# Fractal 8278/8366 | entropy=3.13 | sn=0.175
# Fractal 8279/8366 | entropy=3.04 | sn=0.172
# Fractal 8280/8366 | entropy=2.65 | sn=0.156
# Fractal 8281/8366 | entropy=2.31 | sn=0.142
# Fractal 8282/8366 | entropy=1.86 | sn=0.124
# Fractal 8283/8366 | entropy=2.23 | sn=0.139
# Fractal 8284/8366 | entropy=2.14 | sn=0.135
# Fractal 8285/8366 | entropy=2.06 | sn=0.132
# Fractal 8286/8366 | entropy=2.38 | sn=0.145
# Fractal 8287/8366 | entropy=1.64 | sn=0.116
# Fractal 8288/8366 | entropy=1.46 | sn=0.108
# Fractal 8289/8366 | entropy=2.05 | sn=0.132
# Fractal 8290/8366 | entropy=2.73 | sn=0.159
# Fractal 8291/8366 | entropy=2.98 | sn=0.169
# Fractal 8292/8366 | entropy=2.91 | sn=0.167
# Fractal 8293/8366 | entropy=2.88 | sn=0.165
# Fractal 8294/8366 | entropy=1.74 | sn=0.120
# Fractal 8295/8366 | entropy=1.15 | sn=0.096
# Fractal 8296/8366 | entropy=2.53 | sn=0.151
# Fractal 8297/8366 | entropy=3.01 | sn=0.170
# Fractal 8298/8366 | entropy=3.08 | sn=0.173
# Fractal 8299/8366 | entropy=3.03 | sn=0.171
# Fractal 8300/8366 | entropy=3.17 | sn=0.177
# Fractal 8301/8366 | entropy=3.04 | sn=0.171
# Fractal 8302/8366 | entropy=2.96 | sn=0.168
# Fractal 8303/8366 | entropy=2.97 | sn=0.169
# Fractal 8304/8366 | entropy=3.26 | sn=0.180
# Fractal 8305/8366 | entropy=3.19 | sn=0.178
# Fractal 8306/8366 | entropy=2.93 | sn=0.167
# Fractal 8307/8366 | entropy=3.03 | sn=0.171
# Fractal 8308/8366 | entropy=2.89 | sn=0.166
# Fractal 8309/8366 | entropy=2.98 | sn=0.169
# Fractal 8310/8366 | entropy=2.57 | sn=0.153
# Fractal 8311/8366 | entropy=1.91 | sn=0.126
# Fractal 8312/8366 | entropy=3.23 | sn=0.179
# Fractal 8313/8366 | entropy=3.25 | sn=0.180
# Fractal 8314/8366 | entropy=3.24 | sn=0.179
# Fractal 8315/8366 | entropy=3.12 | sn=0.175
# Fractal 8316/8366 | entropy=3.25 | sn=0.180
# Fractal 8317/8366 | entropy=2.77 | sn=0.161
# Fractal 8318/8366 | entropy=3.12 | sn=0.175
# Fractal 8319/8366 | entropy=3.07 | sn=0.173
# Fractal 8320/8366 | entropy=2.26 | sn=0.140
# Fractal 8321/8366 | entropy=0.53 | sn=0.071
# Fractal 8322/8366 | entropy=1.57 | sn=0.113
# Fractal 8323/8366 | entropy=2.60 | sn=0.154
# Fractal 8324/8366 | entropy=2.63 | sn=0.155
# Fractal 8325/8366 | entropy=2.57 | sn=0.153
# Fractal 8326/8366 | entropy=1.27 | sn=0.101
# Fractal 8327/8366 | entropy=1.10 | sn=0.094
# Fractal 8328/8366 | entropy=0.88 | sn=0.085
# Fractal 8329/8366 | entropy=1.97 | sn=0.129
# Fractal 8330/8366 | entropy=2.72 | sn=0.159
# Fractal 8331/8366 | entropy=2.82 | sn=0.163
# Fractal 8332/8366 | entropy=3.21 | sn=0.178
# Fractal 8333/8366 | entropy=3.20 | sn=0.178
# Fractal 8334/8366 | entropy=2.64 | sn=0.156
# Fractal 8335/8366 | entropy=3.01 | sn=0.171
# Fractal 8336/8366 | entropy=3.05 | sn=0.172
# Fractal 8337/8366 | entropy=3.03 | sn=0.171
# Fractal 8338/8366 | entropy=2.26 | sn=0.140
# Fractal 8339/8366 | entropy=3.19 | sn=0.178
# Fractal 8340/8366 | entropy=3.12 | sn=0.175
# Fractal 8341/8366 | entropy=3.13 | sn=0.175
# Fractal 8342/8366 | entropy=2.09 | sn=0.134
# Fractal 8343/8366 | entropy=0.60 | sn=0.074
# Fractal 8344/8366 | entropy=0.00 | sn=0.050
# Fractal 8345/8366 | entropy=0.00 | sn=0.050
# Fractal 8346/8366 | entropy=0.00 | sn=0.050
# Fractal 8347/8366 | entropy=2.16 | sn=0.137
# Fractal 8348/8366 | entropy=3.33 | sn=0.183
# Fractal 8349/8366 | entropy=3.34 | sn=0.184
# Fractal 8350/8366 | entropy=3.12 | sn=0.175
# Fractal 8351/8366 | entropy=2.85 | sn=0.164
# Fractal 8352/8366 | entropy=3.13 | sn=0.175
# Fractal 8353/8366 | entropy=3.05 | sn=0.172
# Fractal 8354/8366 | entropy=2.93 | sn=0.167
# Fractal 8355/8366 | entropy=2.94 | sn=0.168
# Fractal 8356/8366 | entropy=3.07 | sn=0.173
# Fractal 8357/8366 | entropy=3.04 | sn=0.172
# Fractal 8358/8366 | entropy=2.92 | sn=0.167
# Fractal 8359/8366 | entropy=3.18 | sn=0.177
# Fractal 8360/8366 | entropy=3.22 | sn=0.179
# Fractal 8361/8366 | entropy=3.14 | sn=0.175
# Fractal 8362/8366 | entropy=3.00 | sn=0.170
# Fractal 8363/8366 | entropy=3.32 | sn=0.183
# Fractal 8364/8366 | entropy=2.96 | sn=0.168
# Fractal 8365/8366 | entropy=2.90 | sn=0.166
# Fractal 8366/8366 | entropy=2.86 | sn=0.164
#
# Fractal time: 371.5724322795868

# %%
# ==========================================================
# SAVE OUTPUTS
# ==========================================================

with rasterio.open(
    OUTPUT_ADAPTIVE,
    "w",
    **profile
) as dst:

    # rasterio expects: (bands, height, width)
    dst.write(
        np.transpose(adaptive_uint8, (2, 0, 1))
    )

print("\nGeoTIFF output saved.")


# ==========================================================
# OPTIONAL GP SAVE
# ==========================================================

if USE_GAUSSIAN_PROCESS:

    gp_uint8 = np.clip(
        gp_result,
        0,
        255
    ).astype(np.uint8)

    with rasterio.open(
        OUTPUT_GP,
        "w",
        **profile
    ) as dst:

        dst.write(
            np.transpose(gp_uint8, (2, 0, 1))
        )

    print("GP GeoTIFF output saved.")


# ==========================================================
# ENTROPY MAP
# ==========================================================

# entropy map only uses first channel
entropy_map = build_entropy_map(
    img.shape,
    coords,
    entropy_values
)


# ==========================================================
# MAIN COMPARISON FIGURE
# ==========================================================

if USE_GAUSSIAN_PROCESS:
    n_cols = 5
else:
    n_cols = 4

fig, ax = plt.subplots(
    1,
    n_cols,
    figsize=(6 * n_cols, 6)
)

# ----------------------------------------------------------
# ORIGINAL IMAGE
# ----------------------------------------------------------

ax[0].imshow(img)

ax[0].set_title("Original RGB")
ax[0].axis("off")


# ==========================================================
# CROP REGION
# ==========================================================

h, w, _ = img.shape

crop_size = 64

cy = h // 2
cx = w // 2

y0 = max(0, cy - crop_size // 2)
x0 = max(0, cx - crop_size // 2)

# draw crop rectangle
rect = plt.Rectangle(
    (x0, y0),
    crop_size,
    crop_size,
    edgecolor="cyan",
    facecolor="none",
    linewidth=2
)

ax[0].add_patch(rect)


# ----------------------------------------------------------
# FRACTAL UPSCALED IMAGE
# ----------------------------------------------------------

ax[1].imshow(adaptive_uint8)

ax[1].set_title("Adaptive Fractal")
ax[1].axis("off")


# ----------------------------------------------------------
# ORIGINAL CROP
# ----------------------------------------------------------

orig_crop = img[
    y0:y0 + crop_size,
    x0:x0 + crop_size
]

ax[2].imshow(
    orig_crop,
    interpolation="nearest"
)

ax[2].set_title("Original Crop")
ax[2].axis("off")


# ----------------------------------------------------------
# FRACTAL UPSCALED CROP
# ----------------------------------------------------------

y0s = y0 * SCALE
x0s = x0 * SCALE

crop_scaled = crop_size * SCALE

fractal_crop = adaptive_uint8[
    y0s:y0s + crop_scaled,
    x0s:x0s + crop_scaled
]

ax[3].imshow(
    fractal_crop,
    interpolation="nearest"
)

ax[3].set_title("Fractal Upscaled Crop")
ax[3].axis("off")


# ----------------------------------------------------------
# OPTIONAL GP CROP
# ----------------------------------------------------------

if USE_GAUSSIAN_PROCESS:

    gp_crop = gp_uint8[
        y0s:y0s + crop_scaled,
        x0s:x0s + crop_scaled
    ]

    ax[4].imshow(
        gp_crop,
        interpolation="nearest"
    )

    ax[4].set_title("GP Upscaled Crop")
    ax[4].axis("off")


plt.tight_layout()
plt.show()


# ==========================================================
# ENTROPY MAP FIGURE (SEPARATE)
# ==========================================================

fig_entropy, ax_entropy = plt.subplots(
    figsize=(8, 8)
)

im = ax_entropy.imshow(
    entropy_map,
    cmap="inferno"
)

ax_entropy.set_title("Entropy Heatmap")
ax_entropy.axis("off")

plt.colorbar(
    im,
    ax=ax_entropy,
    fraction=0.046,
    pad=0.04
)

plt.tight_layout()
plt.show()


# ==========================================================
# SUMMARY
# ==========================================================

print("\n======================")
print("SUMMARY")
print("======================")

print(f"Max entropy: {np.max(entropy_values):.2f}")
print(f"Mean entropy: {np.mean(entropy_values):.2f}")

print(f"Fractal output shape: {adaptive_uint8.shape}")

if USE_GAUSSIAN_PROCESS:
    print(f"GP output shape: {gp_uint8.shape}")

print("\nDone.")
# Out:
# GeoTIFF output saved.
# ======================
# SUMMARY
# ======================
# Max entropy: 3.47
# Mean entropy: 2.72
# Fractal output shape: (2710, 2850, 3)
#
# Done.

# %%
# ==========================================================
# 1D FRACTAL INTERPOLATION
# DIFFERENT sn VALUES
# ==========================================================

import numpy as np
import matplotlib.pyplot as plt


# ==========================================================
# SAMPLE FUNCTION
# ==========================================================

def f(x):

    return (
        np.sin(2 * np.pi * x)
        +
        0.3 * np.cos(10 * np.pi * x)
    )


# ==========================================================
# LOW-RES SAMPLE POINTS
# ==========================================================

x_coarse = np.linspace(0, 1, 12)

y_coarse = f(x_coarse)


# ==========================================================
# TRUE HIGH-RES FUNCTION
# ==========================================================

x_true = np.linspace(0, 1, 2000)

y_true = f(x_true)


# ==========================================================
# sn VALUES TO COMPARE
# ==========================================================

sn_values = [
    0.01,
    0.05,
    0.12,
    0.25
]


# ==========================================================
# DISPLAY
# ==========================================================

plt.figure(figsize=(14, 8))

# ----------------------------------------------------------
# TRUE FUNCTION
# ----------------------------------------------------------

plt.plot(
    x_true,
    y_true,
    linewidth=3,
    alpha=0.5,
    label="True Function"
)

# ----------------------------------------------------------
# FRACTAL INTERPOLATIONS
# ----------------------------------------------------------

for sn in sn_values:

    fractal_y = fractal_interpolate_1d(
        y_coarse,
        scale=10,
        sn=sn,
        iterations=1
    )

    x_fractal = np.linspace(
        0,
        1,
        len(fractal_y)
    )

    plt.plot(
        x_fractal,
        fractal_y,
        linewidth=2,
        label=f"sn = {sn}"
    )


# ----------------------------------------------------------
# ORIGINAL SAMPLE POINTS
# ----------------------------------------------------------

plt.scatter(
    x_coarse,
    y_coarse,
    s=70,
    zorder=5,
    label="Original Samples"
)

plt.title(
    "Effect of Fractal Parameter sn on 1D Fractal Interpolation",
    fontsize=16
)

plt.xlabel("x", fontsize=12)

plt.ylabel("f(x)", fontsize=12)

plt.legend()

plt.grid(True)

plt.show()
